# %% [markdown]
# ### References
#
# https://www.tensorflow.org/tutorials/load_data/images
#
# https://www.tensorflow.org/api_docs/python/tf/data/Dataset
#
# https://www.youtube.com/watch?v=yH1cF7GnoIo
#
# https://www.datacamp.com/community/tutorials/tensorflow-tutorial

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import metrics
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping,TensorBoard, ReduceLROnPlateau
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.layers import BatchNormalization, LeakyReLU, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

import os
import numpy as np

# plotting
import matplotlib.pyplot as plt
import pathlib
from PIL import Image
import IPython.display as display

# to display confusion matrix
import seaborn as sn
import pandas as pd

# to determine the most voted
import collections

# %% [markdown]
# ### Aux functions

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == classNames

def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_png(img, channels=3)
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
  # resize the image to the desired size.
  return tf.image.resize(img, [32,32])

def get_bytes_and_label(file_path):
  label = get_label(file_path)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

def show_data(s1,l1, s2,l2, labels, min):
    fig, ax = plt.subplots()
    X = np.arange(len(s1))

    models = labels
    plt.bar(X, s1, width = 0.4, color = 'b', label=l1)
    plt.bar(X + 0.4, s2, color = 'r', width = 0.4, label = l2)
    plt.xticks(X + 0.4 / 2, models)
    plt.ylim(top = 100, bottom = min)
    plt.legend(loc='upper left')
    plt.show()

def show_batch(image_batch, label_batch):
  columns = 6
  rows = BATCH_SIZE / columns + 1  
  plt.figure(figsize=(10, 2 * rows))
  for n in range(BATCH_SIZE):
      ax = plt.subplot(int(rows), columns, n+1)
      plt.imshow((image_batch[n]))
      plt.title(classNames[label_batch[n]==1][0])
      plt.axis('off')


def show_history(history):
    print(history.history.keys())

    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='lower right')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper right')
    plt.show()    


def show_accuracies(labels, test, val): 

    fig, ax = plt.subplots()
    X = np.arange(len(test))

    plt.bar(X, test, width = 0.4, color = 'b', label='test')
    plt.bar(X + 0.4, val, color = 'r', width = 0.4, label = "val")
    plt.xticks(X + 0.4 / 2, labels)
    plt.ylim(top = 1.0, bottom = 0.97)
    plt.legend(loc='upper left')
    plt.show()    



def show_misclassified(predictions, ground_truth, images, num_rows = 5, num_cols=3):
    
    # Plot the first X test images with wrong predictions.
    num_images = num_rows*num_cols
    print(num_images)
    plt.figure(figsize=(2*2*num_cols, 2*num_rows))
    i = 0
    k = 0
    while k < len(images) and i < num_images:
        predicted_label = np.argmax(predictions[k])
        gt = np.where(ground_truth[k])[0][0]
        if predicted_label != gt:
            plt.subplot(num_rows, 2*num_cols, 2*i+1)
            plot_image(k, predictions[k], gt, images)
            plt.subplot(num_rows, 2*num_cols, 2*i+2)
            plot_value_array(k, predictions[k], ground_truth)
            i += 1
        k += 1
    plt.tight_layout()
    plt.show()


def plot_image(i, predictions_array, true_label, img):
    predictions_array, true_label, img = predictions_array, true_label, img[i]
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    
    plt.imshow(img, cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    if predicted_label == true_label:
      color = 'blue'
    else:
      color = 'red'
    
    plt.xlabel("{} {:2.0f}% ({})".format(classNames[predicted_label],
                                100*np.max(predictions_array),
                                classNames[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array, true_label[i]
    plt.grid(False)
    plt.xticks(range(8))
    plt.yticks([])
    thisplot = plt.bar(range(8), predictions_array, color="#777777")
    plt.ylim([0, 1])
    predicted_label = np.argmax(predictions_array)

    thisplot[predicted_label].set_color('red')
    thisplot[np.where(true_label)[0][0]].set_color('blue')   



def show_confusion_matrix(mat, classes):

    df_cm = pd.DataFrame(mat, range(classes), range(classes))
    plt.figure(figsize=(15,10))
    sn.set(font_scale=1.4) # for label size
    sn.heatmap(df_cm, annot=True, annot_kws={"size": 16}, fmt='d') # font size

    plt.show()

# %%
def prepare_callbacks(file_path):

    checkpointer = ModelCheckpoint(filepath= file_path, 
                               monitor = 'val_accuracy',
                               verbose=1, 
                               save_weights_only=True,
                               save_best_only=True)


    earlyStopper = EarlyStopping(monitor='val_loss', min_delta = 0.0001, patience = 15, verbose = 1)

    reduceLR = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=0.000000001, verbose = 1)

    return [checkpointer, earlyStopper, reduceLR]

# %% [markdown]
# ### Batch size
#
# Batch size is an important parameter when training a network. It can influence speed and generalization, not necessarily in the same direction. There is no golden rule for the batch size but 32 is a commom number to start with.
#
# In here we go to 64 to achieve faster training epochs (rather than 32)
#
# See: https://machinelearningmastery.com/how-to-control-the-speed-and-stability-of-training-neural-networks-with-gradient-descent-batch-size/

# %%
BATCH_SIZE = 64
IMAGE_SIZE = 32

# %% [markdown]
# ### Prepare to load images

# %%
data_dir = pathlib.Path('../gtsrb/train_images/')
  
classNames = np.array(os.listdir(data_dir))
NUM_CLASSES = len(classNames)
classNames
# Out:
# array(['00000', '00001', '00002', '00003', '00004', '00005', '00006',
#        '00007'], dtype='<U5')

# %% [markdown]
# ### Loading images takes place in here

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

listset = tf.data.Dataset.list_files("../gtsrb/train_images/*/*.png")
dataset = listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)

# %% [markdown]
# ### Information about image shape and size of training set

# %%
t = next(iter(dataset))
print(t[0].shape, t[1].shape)

# note: this only works if dataset is not repeating
dataset_length = tf.data.experimental.cardinality(dataset).numpy()
print("Total images in dataset: ", dataset_length)
# Out:
# (32, 32, 3) (8,)
# Total images in dataset:  10200

# %% [markdown]
# ### Preparing training, validation and test datasets

# %%
dataSolo = dataset
dataSolo = dataSolo.cache()
dataSolo = dataSolo.shuffle(buffer_size = dataset_length)
dataSolo = dataSolo.prefetch(buffer_size=10200)
dataSolo = dataSolo.batch(batch_size=BATCH_SIZE)

# %%
val_listset = tf.data.Dataset.list_files("../gtsrb/val_images/*/*.png")
val_dataset_length = val_listset.cardinality().numpy()
print("Total images in validatation dataset: ", val_dataset_length)

valset = val_listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
valset = valset.cache()
valset = valset.shuffle(buffer_size = 2580)
valset = valset.batch(batch_size = 2580)
valset = valset.prefetch(buffer_size = AUTOTUNE)
# Out:
# Total images in validatation dataset:  2580

# %%
test_listset = tf.data.Dataset.list_files("../gtsrb/test_images_per_folder/*/*.png")
test_dataset_length = test_listset.cardinality().numpy()
print("Total images in validatation dataset: ", test_dataset_length)

testset = test_listset.map(get_bytes_and_label, num_parallel_calls = AUTOTUNE)
testset = testset.batch(batch_size = BATCH_SIZE)
# Out:
# Total images in validatation dataset:  4170

# %% [markdown]
# ### Show a batch of training images

# %%
        
        
image_batch, label_batch = next(iter(dataSolo))        
show_batch(image_batch, label_batch.numpy())

# %% [markdown]
# ### Build a CNN network

# %%
def create_model(classCount, imgSize, channels):

    modelLogits = Sequential()
    
    modelLogits.add(Conv2D(128, (5, 5),
                input_shape=(imgSize, imgSize, channels)))         
    modelLogits.add(LeakyReLU(alpha=0.01))  
    modelLogits.add(BatchNormalization())
    modelLogits.add(Dropout(0.5)) 

    modelLogits.add(Conv2D(196, (5, 5) )) 
    modelLogits.add(LeakyReLU(alpha=0.01))
    modelLogits.add(MaxPooling2D(pool_size=(2, 2)))
    modelLogits.add(BatchNormalization())
    modelLogits.add(Dropout(0.5)) 

    modelLogits.add(Conv2D(256, (5, 5) ) )   
    modelLogits.add(LeakyReLU(alpha=0.01))
    modelLogits.add(MaxPooling2D(pool_size=(2, 2)))
    modelLogits.add(BatchNormalization())
    modelLogits.add(Dropout(0.5)) 
    
    modelLogits.add(Flatten())
    modelLogits.add(Dense(384))
    modelLogits.add(LeakyReLU(alpha=0.0))             
    modelLogits.add(Dropout(0.5)) 
    
    modelLogits.add(Dense(classCount))
    
    output = Activation('softmax')(modelLogits.output)

    model = tf.keras.Model(modelLogits.inputs, output)
    
    opt = Adam(lr=0.0001)
    model.compile(optimizer = opt, loss='categorical_crossentropy', metrics=[ 'accuracy'])
    return model, modelLogits

# %%
NUM_MODELS = 9

# %%
def train_models(train, val,file_path_prefix):

    models = []
    histories = []
    
    for i in range(NUM_MODELS):

        model, modelL = create_model(NUM_CLASSES,IMAGE_SIZE,3)

        callbacks = prepare_callbacks(f'{file_path_prefix}_{i:02}/cp.ckpt')

        hist = model.fit(train, 
                              epochs=100, 
                              validation_data = val, 
                              callbacks = callbacks)

        models.append([model, modelL])
        histories.append(hist)
    
    return models,histories_
 

file_path_prefix = f'd:/temp/ensembles/model_V1'
modelsV1, histories_V1 = train_models(dataSolo, valset, file_path_prefix)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.9190 - accuracy: 0.2359 - val_loss: 2.4978 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8450 - accuracy: 0.4068 - val_loss: 2.5432 - val_accuracy: 0.2039
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.20388, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.9900 - accuracy: 0.6533 - val_loss: 1.2607 - val_accuracy: 0.5663
#
# Epoch 00003: val_accuracy improved from 0.20388 to 0.56628, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.5770 - accuracy: 0.8049 - val_loss: 0.4457 - val_accuracy: 0.8500
#
# Epoch 00004: val_accuracy improved from 0.56628 to 0.85000, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3636 - accuracy: 0.8736 - val_loss: 0.2798 - val_accuracy: 0.9027
#
# Epoch 00005: val_accuracy improved from 0.85000 to 0.90271, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2722 - accuracy: 0.9101 - val_loss: 0.1864 - val_accuracy: 0.9353
#
# Epoch 00006: val_accuracy improved from 0.90271 to 0.93527, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2185 - accuracy: 0.9292 - val_loss: 0.1415 - val_accuracy: 0.9516
#
# Epoch 00007: val_accuracy improved from 0.93527 to 0.95155, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1832 - accuracy: 0.9373 - val_loss: 0.1132 - val_accuracy: 0.9620
#
# Epoch 00008: val_accuracy improved from 0.95155 to 0.96202, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1303 - accuracy: 0.9566 - val_loss: 0.1058 - val_accuracy: 0.9632
#
# Epoch 00009: val_accuracy improved from 0.96202 to 0.96318, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1196 - accuracy: 0.9627 - val_loss: 0.1099 - val_accuracy: 0.9647
#
# Epoch 00010: val_accuracy improved from 0.96318 to 0.96473, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0990 - accuracy: 0.9671 - val_loss: 0.0944 - val_accuracy: 0.9694
#
# Epoch 00011: val_accuracy improved from 0.96473 to 0.96938, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1011 - accuracy: 0.9662 - val_loss: 0.0900 - val_accuracy: 0.9698
#
# Epoch 00012: val_accuracy improved from 0.96938 to 0.96977, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0712 - accuracy: 0.9764 - val_loss: 0.0604 - val_accuracy: 0.9798
#
# Epoch 00013: val_accuracy improved from 0.96977 to 0.97984, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0674 - accuracy: 0.9763 - val_loss: 0.0634 - val_accuracy: 0.9783
#
# Epoch 00014: val_accuracy did not improve from 0.97984
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0650 - accuracy: 0.9789 - val_loss: 0.0721 - val_accuracy: 0.9764
#
# Epoch 00015: val_accuracy did not improve from 0.97984
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0433 - accuracy: 0.9843 - val_loss: 0.0620 - val_accuracy: 0.9810
#
# Epoch 00016: val_accuracy improved from 0.97984 to 0.98101, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0490 - accuracy: 0.9842 - val_loss: 0.0519 - val_accuracy: 0.9814
#
# Epoch 00017: val_accuracy improved from 0.98101 to 0.98140, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0401 - accuracy: 0.9860 - val_loss: 0.0681 - val_accuracy: 0.9783
#
# Epoch 00018: val_accuracy did not improve from 0.98140
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0375 - accuracy: 0.9863 - val_loss: 0.0584 - val_accuracy: 0.9814
#
# Epoch 00019: val_accuracy did not improve from 0.98140
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0373 - accuracy: 0.9888 - val_loss: 0.0892 - val_accuracy: 0.9729
#
# Epoch 00020: val_accuracy did not improve from 0.98140
# Epoch 21/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0346 - accuracy: 0.9881 - val_loss: 0.1019 - val_accuracy: 0.9690
#
# Epoch 00021: val_accuracy did not improve from 0.98140
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0283 - accuracy: 0.9905 - val_loss: 0.0820 - val_accuracy: 0.9729
#
# Epoch 00022: val_accuracy did not improve from 0.98140
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0274 - accuracy: 0.9914 - val_loss: 0.0676 - val_accuracy: 0.9767
#
# Epoch 00023: val_accuracy did not improve from 0.98140
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.0755 - val_accuracy: 0.9760
#
# Epoch 00024: val_accuracy did not improve from 0.98140
# Epoch 25/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0222 - accuracy: 0.9939 - val_loss: 0.0642 - val_accuracy: 0.9795
#
# Epoch 00025: val_accuracy did not improve from 0.98140
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0149 - accuracy: 0.9957 - val_loss: 0.0739 - val_accuracy: 0.9779
#
# Epoch 00026: val_accuracy did not improve from 0.98140
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0131 - accuracy: 0.9951 - val_loss: 0.0642 - val_accuracy: 0.9798
#
# Epoch 00027: val_accuracy did not improve from 0.98140
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.0530 - val_accuracy: 0.9849
#
# Epoch 00028: val_accuracy improved from 0.98140 to 0.98488, saving model to d:/temp/ensembles/model_V1_00\cp.ckpt
# Epoch 29/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0118 - accuracy: 0.9967 - val_loss: 0.0577 - val_accuracy: 0.9829
#
# Epoch 00029: val_accuracy did not improve from 0.98488
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0105 - accuracy: 0.9965 - val_loss: 0.0523 - val_accuracy: 0.9849
#
# Epoch 00030: val_accuracy did not improve from 0.98488
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0611 - val_accuracy: 0.9837
#
# Epoch 00031: val_accuracy did not improve from 0.98488
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.0617 - val_accuracy: 0.9822
#
# Epoch 00032: val_accuracy did not improve from 0.98488
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 00032: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 15ms/step - loss: 2.9446 - accuracy: 0.2263 - val_loss: 2.1142 - val_accuracy: 0.2372
#
# Epoch 00001: val_accuracy improved from -inf to 0.23721, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8874 - accuracy: 0.3915 - val_loss: 2.7328 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.23721
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.1022 - accuracy: 0.6209 - val_loss: 1.5555 - val_accuracy: 0.3659
#
# Epoch 00003: val_accuracy improved from 0.23721 to 0.36589, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6111 - accuracy: 0.7970 - val_loss: 0.5653 - val_accuracy: 0.8140
#
# Epoch 00004: val_accuracy improved from 0.36589 to 0.81395, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3965 - accuracy: 0.8627 - val_loss: 0.2447 - val_accuracy: 0.9240
#
# Epoch 00005: val_accuracy improved from 0.81395 to 0.92403, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2704 - accuracy: 0.9098 - val_loss: 0.1934 - val_accuracy: 0.9380
#
# Epoch 00006: val_accuracy improved from 0.92403 to 0.93798, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2300 - accuracy: 0.9196 - val_loss: 0.1211 - val_accuracy: 0.9609
#
# Epoch 00007: val_accuracy improved from 0.93798 to 0.96085, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1707 - accuracy: 0.9468 - val_loss: 0.1231 - val_accuracy: 0.9616
#
# Epoch 00008: val_accuracy improved from 0.96085 to 0.96163, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1396 - accuracy: 0.9546 - val_loss: 0.1161 - val_accuracy: 0.9589
#
# Epoch 00009: val_accuracy did not improve from 0.96163
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1274 - accuracy: 0.9604 - val_loss: 0.1110 - val_accuracy: 0.9636
#
# Epoch 00010: val_accuracy improved from 0.96163 to 0.96357, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0963 - accuracy: 0.9677 - val_loss: 0.0948 - val_accuracy: 0.9690
#
# Epoch 00011: val_accuracy improved from 0.96357 to 0.96899, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0783 - accuracy: 0.9737 - val_loss: 0.0914 - val_accuracy: 0.9694
#
# Epoch 00012: val_accuracy improved from 0.96899 to 0.96938, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0747 - accuracy: 0.9733 - val_loss: 0.0865 - val_accuracy: 0.9709
#
# Epoch 00013: val_accuracy improved from 0.96938 to 0.97093, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0637 - accuracy: 0.9801 - val_loss: 0.0751 - val_accuracy: 0.9729
#
# Epoch 00014: val_accuracy improved from 0.97093 to 0.97287, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0560 - accuracy: 0.9820 - val_loss: 0.0854 - val_accuracy: 0.9705
#
# Epoch 00015: val_accuracy did not improve from 0.97287
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0500 - accuracy: 0.9840 - val_loss: 0.0764 - val_accuracy: 0.9740
#
# Epoch 00016: val_accuracy improved from 0.97287 to 0.97403, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0536 - accuracy: 0.9821 - val_loss: 0.0629 - val_accuracy: 0.9795
#
# Epoch 00017: val_accuracy improved from 0.97403 to 0.97946, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0362 - accuracy: 0.9873 - val_loss: 0.0593 - val_accuracy: 0.9791
#
# Epoch 00018: val_accuracy did not improve from 0.97946
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0308 - accuracy: 0.9911 - val_loss: 0.0838 - val_accuracy: 0.9729
#
# Epoch 00019: val_accuracy did not improve from 0.97946
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0309 - accuracy: 0.9890 - val_loss: 0.0651 - val_accuracy: 0.9783
#
# Epoch 00020: val_accuracy did not improve from 0.97946
# Epoch 21/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0345 - accuracy: 0.9877 - val_loss: 0.0499 - val_accuracy: 0.9849
#
# Epoch 00021: val_accuracy improved from 0.97946 to 0.98488, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0304 - accuracy: 0.9888 - val_loss: 0.0634 - val_accuracy: 0.9822
#
# Epoch 00022: val_accuracy did not improve from 0.98488
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0209 - accuracy: 0.9937 - val_loss: 0.0641 - val_accuracy: 0.9798
#
# Epoch 00023: val_accuracy did not improve from 0.98488
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0295 - accuracy: 0.9893 - val_loss: 0.0606 - val_accuracy: 0.9798
#
# Epoch 00024: val_accuracy did not improve from 0.98488
# Epoch 25/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.0627 - val_accuracy: 0.9787
#
# Epoch 00025: val_accuracy did not improve from 0.98488
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.0813 - val_accuracy: 0.9748
#
# Epoch 00026: val_accuracy did not improve from 0.98488
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0171 - accuracy: 0.9934 - val_loss: 0.0514 - val_accuracy: 0.9841
#
# Epoch 00027: val_accuracy did not improve from 0.98488
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0195 - accuracy: 0.9941 - val_loss: 0.0581 - val_accuracy: 0.9833
#
# Epoch 00028: val_accuracy did not improve from 0.98488
# Epoch 29/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0460 - val_accuracy: 0.9853
#
# Epoch 00029: val_accuracy improved from 0.98488 to 0.98527, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0094 - accuracy: 0.9976 - val_loss: 0.0462 - val_accuracy: 0.9864
#
# Epoch 00030: val_accuracy improved from 0.98527 to 0.98643, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0110 - accuracy: 0.9962 - val_loss: 0.0446 - val_accuracy: 0.9864
#
# Epoch 00031: val_accuracy did not improve from 0.98643
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0165 - accuracy: 0.9953 - val_loss: 0.0430 - val_accuracy: 0.9860
#
# Epoch 00032: val_accuracy did not improve from 0.98643
# Epoch 33/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.0387 - val_accuracy: 0.9876
#
# Epoch 00033: val_accuracy improved from 0.98643 to 0.98760, saving model to d:/temp/ensembles/model_V1_01\cp.ckpt
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.0500 - val_accuracy: 0.9845
#
# Epoch 00034: val_accuracy did not improve from 0.98760
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.0579 - val_accuracy: 0.9787
#
# Epoch 00035: val_accuracy did not improve from 0.98760
# Epoch 36/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.0624 - val_accuracy: 0.9806
#
# Epoch 00036: val_accuracy did not improve from 0.98760
# Epoch 37/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.0574 - val_accuracy: 0.9806
#
# Epoch 00037: val_accuracy did not improve from 0.98760
# Epoch 38/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0083 - accuracy: 0.9980 - val_loss: 0.0473 - val_accuracy: 0.9829
#
# Epoch 00038: val_accuracy did not improve from 0.98760
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 39/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0523 - val_accuracy: 0.9837
#
# Epoch 00039: val_accuracy did not improve from 0.98760
# Epoch 40/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0066 - accuracy: 0.9979 - val_loss: 0.0538 - val_accuracy: 0.9833
#
# Epoch 00040: val_accuracy did not improve from 0.98760
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0063 - accuracy: 0.9976 - val_loss: 0.0502 - val_accuracy: 0.9841
#
# Epoch 00041: val_accuracy did not improve from 0.98760
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0045 - accuracy: 0.9985 - val_loss: 0.0525 - val_accuracy: 0.9841
#
# Epoch 00042: val_accuracy did not improve from 0.98760
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0069 - accuracy: 0.9981 - val_loss: 0.0470 - val_accuracy: 0.9849
#
# Epoch 00043: val_accuracy did not improve from 0.98760
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0065 - accuracy: 0.9974 - val_loss: 0.0443 - val_accuracy: 0.9864
#
# Epoch 00044: val_accuracy did not improve from 0.98760
# Epoch 45/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0415 - val_accuracy: 0.9868
#
# Epoch 00045: val_accuracy did not improve from 0.98760
# Epoch 46/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0447 - val_accuracy: 0.9853
#
# Epoch 00046: val_accuracy did not improve from 0.98760
# Epoch 47/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 0.0463 - val_accuracy: 0.9849
#
# Epoch 00047: val_accuracy did not improve from 0.98760
# Epoch 48/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0491 - val_accuracy: 0.9853
#
# Epoch 00048: val_accuracy did not improve from 0.98760
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00048: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 18ms/step - loss: 3.0600 - accuracy: 0.2302 - val_loss: 2.6243 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8426 - accuracy: 0.4006 - val_loss: 2.4052 - val_accuracy: 0.1752
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.17519, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.0635 - accuracy: 0.6262 - val_loss: 1.4145 - val_accuracy: 0.5140
#
# Epoch 00003: val_accuracy improved from 0.17519 to 0.51395, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6323 - accuracy: 0.7811 - val_loss: 0.6563 - val_accuracy: 0.7756
#
# Epoch 00004: val_accuracy improved from 0.51395 to 0.77558, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3954 - accuracy: 0.8660 - val_loss: 0.2596 - val_accuracy: 0.9116
#
# Epoch 00005: val_accuracy improved from 0.77558 to 0.91163, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2985 - accuracy: 0.9032 - val_loss: 0.1671 - val_accuracy: 0.9504
#
# Epoch 00006: val_accuracy improved from 0.91163 to 0.95039, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2237 - accuracy: 0.9255 - val_loss: 0.1524 - val_accuracy: 0.9519
#
# Epoch 00007: val_accuracy improved from 0.95039 to 0.95194, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1673 - accuracy: 0.9444 - val_loss: 0.1210 - val_accuracy: 0.9605
#
# Epoch 00008: val_accuracy improved from 0.95194 to 0.96047, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1450 - accuracy: 0.9534 - val_loss: 0.1071 - val_accuracy: 0.9620
#
# Epoch 00009: val_accuracy improved from 0.96047 to 0.96202, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1191 - accuracy: 0.9621 - val_loss: 0.1120 - val_accuracy: 0.9624
#
# Epoch 00010: val_accuracy improved from 0.96202 to 0.96240, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1088 - accuracy: 0.9669 - val_loss: 0.0881 - val_accuracy: 0.9702
#
# Epoch 00011: val_accuracy improved from 0.96240 to 0.97016, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0880 - accuracy: 0.9718 - val_loss: 0.0780 - val_accuracy: 0.9733
#
# Epoch 00012: val_accuracy improved from 0.97016 to 0.97326, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0816 - accuracy: 0.9760 - val_loss: 0.0748 - val_accuracy: 0.9729
#
# Epoch 00013: val_accuracy did not improve from 0.97326
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0654 - accuracy: 0.9800 - val_loss: 0.0974 - val_accuracy: 0.9659
#
# Epoch 00014: val_accuracy did not improve from 0.97326
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0594 - accuracy: 0.9823 - val_loss: 0.1177 - val_accuracy: 0.9616
#
# Epoch 00015: val_accuracy did not improve from 0.97326
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0474 - accuracy: 0.9863 - val_loss: 0.0678 - val_accuracy: 0.9760
#
# Epoch 00016: val_accuracy improved from 0.97326 to 0.97597, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0516 - accuracy: 0.9821 - val_loss: 0.0664 - val_accuracy: 0.9787
#
# Epoch 00017: val_accuracy improved from 0.97597 to 0.97868, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0428 - accuracy: 0.9854 - val_loss: 0.0680 - val_accuracy: 0.9764
#
# Epoch 00018: val_accuracy did not improve from 0.97868
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0456 - accuracy: 0.9851 - val_loss: 0.0695 - val_accuracy: 0.9771
#
# Epoch 00019: val_accuracy did not improve from 0.97868
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0363 - accuracy: 0.9880 - val_loss: 0.0736 - val_accuracy: 0.9752
#
# Epoch 00020: val_accuracy did not improve from 0.97868
# Epoch 21/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0295 - accuracy: 0.9890 - val_loss: 0.0912 - val_accuracy: 0.9682
#
# Epoch 00021: val_accuracy did not improve from 0.97868
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0315 - accuracy: 0.9898 - val_loss: 0.0692 - val_accuracy: 0.9748
#
# Epoch 00022: val_accuracy did not improve from 0.97868
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.0621 - val_accuracy: 0.9771
#
# Epoch 00023: val_accuracy did not improve from 0.97868
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0592 - val_accuracy: 0.9787
#
# Epoch 00024: val_accuracy did not improve from 0.97868
# Epoch 25/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.0750 - val_accuracy: 0.9771
#
# Epoch 00025: val_accuracy did not improve from 0.97868
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0247 - accuracy: 0.9923 - val_loss: 0.0542 - val_accuracy: 0.9818
#
# Epoch 00026: val_accuracy improved from 0.97868 to 0.98178, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0155 - accuracy: 0.9940 - val_loss: 0.0578 - val_accuracy: 0.9814
#
# Epoch 00027: val_accuracy did not improve from 0.98178
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0174 - accuracy: 0.9946 - val_loss: 0.0552 - val_accuracy: 0.9833
#
# Epoch 00028: val_accuracy improved from 0.98178 to 0.98333, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 29/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.0608 - val_accuracy: 0.9845
#
# Epoch 00029: val_accuracy improved from 0.98333 to 0.98450, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0132 - accuracy: 0.9962 - val_loss: 0.0649 - val_accuracy: 0.9783
#
# Epoch 00030: val_accuracy did not improve from 0.98450
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0127 - accuracy: 0.9953 - val_loss: 0.0627 - val_accuracy: 0.9810
#
# Epoch 00031: val_accuracy did not improve from 0.98450
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0112 - accuracy: 0.9962 - val_loss: 0.0512 - val_accuracy: 0.9845
#
# Epoch 00032: val_accuracy did not improve from 0.98450
# Epoch 33/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0104 - accuracy: 0.9967 - val_loss: 0.0549 - val_accuracy: 0.9849
#
# Epoch 00033: val_accuracy improved from 0.98450 to 0.98488, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0109 - accuracy: 0.9958 - val_loss: 0.0537 - val_accuracy: 0.9822
#
# Epoch 00034: val_accuracy did not improve from 0.98488
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0098 - accuracy: 0.9972 - val_loss: 0.0494 - val_accuracy: 0.9853
#
# Epoch 00035: val_accuracy improved from 0.98488 to 0.98527, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 36/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0551 - val_accuracy: 0.9810
#
# Epoch 00036: val_accuracy did not improve from 0.98527
# Epoch 37/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0097 - accuracy: 0.9967 - val_loss: 0.0546 - val_accuracy: 0.9853
#
# Epoch 00037: val_accuracy did not improve from 0.98527
# Epoch 38/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0082 - accuracy: 0.9969 - val_loss: 0.0476 - val_accuracy: 0.9845
#
# Epoch 00038: val_accuracy did not improve from 0.98527
# Epoch 39/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0086 - accuracy: 0.9961 - val_loss: 0.0460 - val_accuracy: 0.9857
#
# Epoch 00039: val_accuracy improved from 0.98527 to 0.98566, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 40/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0086 - accuracy: 0.9975 - val_loss: 0.0484 - val_accuracy: 0.9849
#
# Epoch 00040: val_accuracy did not improve from 0.98566
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0103 - accuracy: 0.9967 - val_loss: 0.0567 - val_accuracy: 0.9837
#
# Epoch 00041: val_accuracy did not improve from 0.98566
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0083 - accuracy: 0.9978 - val_loss: 0.0540 - val_accuracy: 0.9833
#
# Epoch 00042: val_accuracy did not improve from 0.98566
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0080 - accuracy: 0.9974 - val_loss: 0.0533 - val_accuracy: 0.9837
#
# Epoch 00043: val_accuracy did not improve from 0.98566
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0107 - accuracy: 0.9971 - val_loss: 0.0524 - val_accuracy: 0.9853
#
# Epoch 00044: val_accuracy did not improve from 0.98566
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 45/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0079 - accuracy: 0.9970 - val_loss: 0.0533 - val_accuracy: 0.9841
#
# Epoch 00045: val_accuracy did not improve from 0.98566
# Epoch 46/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0488 - val_accuracy: 0.9857
#
# Epoch 00046: val_accuracy did not improve from 0.98566
# Epoch 47/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.0445 - val_accuracy: 0.9857
#
# Epoch 00047: val_accuracy did not improve from 0.98566
# Epoch 48/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0387 - val_accuracy: 0.9899
#
# Epoch 00048: val_accuracy improved from 0.98566 to 0.98992, saving model to d:/temp/ensembles/model_V1_02\cp.ckpt
# Epoch 49/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0397 - val_accuracy: 0.9895
#
# Epoch 00049: val_accuracy did not improve from 0.98992
# Epoch 50/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0415 - val_accuracy: 0.9880
#
# Epoch 00050: val_accuracy did not improve from 0.98992
# Epoch 51/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.0465 - val_accuracy: 0.9872
#
# Epoch 00051: val_accuracy did not improve from 0.98992
# Epoch 52/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0487 - val_accuracy: 0.9860
#
# Epoch 00052: val_accuracy did not improve from 0.98992
# Epoch 53/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0466 - val_accuracy: 0.9864
#
# Epoch 00053: val_accuracy did not improve from 0.98992
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 54/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0435 - val_accuracy: 0.9872
#
# Epoch 00054: val_accuracy did not improve from 0.98992
# Epoch 55/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0442 - val_accuracy: 0.9868
#
# Epoch 00055: val_accuracy did not improve from 0.98992
# Epoch 56/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0429 - val_accuracy: 0.9876
#
# Epoch 00056: val_accuracy did not improve from 0.98992
# Epoch 57/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0035 - accuracy: 0.9995 - val_loss: 0.0434 - val_accuracy: 0.9876
#
# Epoch 00057: val_accuracy did not improve from 0.98992
# Epoch 58/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.0425 - val_accuracy: 0.9880
#
# Epoch 00058: val_accuracy did not improve from 0.98992
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 59/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0049 - accuracy: 0.9989 - val_loss: 0.0423 - val_accuracy: 0.9872
#
# Epoch 00059: val_accuracy did not improve from 0.98992
# Epoch 60/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0414 - val_accuracy: 0.9876
#
# Epoch 00060: val_accuracy did not improve from 0.98992
# Epoch 61/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0409 - val_accuracy: 0.9880
#
# Epoch 00061: val_accuracy did not improve from 0.98992
# Epoch 62/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0042 - accuracy: 0.9987 - val_loss: 0.0413 - val_accuracy: 0.9876
#
# Epoch 00062: val_accuracy did not improve from 0.98992
# Epoch 63/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0042 - accuracy: 0.9990 - val_loss: 0.0437 - val_accuracy: 0.9868
#
# Epoch 00063: val_accuracy did not improve from 0.98992
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 00063: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 15ms/step - loss: 2.9684 - accuracy: 0.2343 - val_loss: 2.3355 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8445 - accuracy: 0.3961 - val_loss: 2.2768 - val_accuracy: 0.2031
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.20310, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.0596 - accuracy: 0.6284 - val_loss: 1.0897 - val_accuracy: 0.6202
#
# Epoch 00003: val_accuracy improved from 0.20310 to 0.62016, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6041 - accuracy: 0.7913 - val_loss: 0.4588 - val_accuracy: 0.8415
#
# Epoch 00004: val_accuracy improved from 0.62016 to 0.84147, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3924 - accuracy: 0.8629 - val_loss: 0.2232 - val_accuracy: 0.9302
#
# Epoch 00005: val_accuracy improved from 0.84147 to 0.93023, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2988 - accuracy: 0.9010 - val_loss: 0.1708 - val_accuracy: 0.9442
#
# Epoch 00006: val_accuracy improved from 0.93023 to 0.94419, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2208 - accuracy: 0.9266 - val_loss: 0.1404 - val_accuracy: 0.9539
#
# Epoch 00007: val_accuracy improved from 0.94419 to 0.95388, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1934 - accuracy: 0.9369 - val_loss: 0.1641 - val_accuracy: 0.9481
#
# Epoch 00008: val_accuracy did not improve from 0.95388
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1476 - accuracy: 0.9489 - val_loss: 0.1335 - val_accuracy: 0.9531
#
# Epoch 00009: val_accuracy did not improve from 0.95388
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1118 - accuracy: 0.9612 - val_loss: 0.1181 - val_accuracy: 0.9562
#
# Epoch 00010: val_accuracy improved from 0.95388 to 0.95620, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1082 - accuracy: 0.9636 - val_loss: 0.1239 - val_accuracy: 0.9570
#
# Epoch 00011: val_accuracy improved from 0.95620 to 0.95698, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0866 - accuracy: 0.9720 - val_loss: 0.1021 - val_accuracy: 0.9636
#
# Epoch 00012: val_accuracy improved from 0.95698 to 0.96357, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0734 - accuracy: 0.9725 - val_loss: 0.1153 - val_accuracy: 0.9601
#
# Epoch 00013: val_accuracy did not improve from 0.96357
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0648 - accuracy: 0.9773 - val_loss: 0.0802 - val_accuracy: 0.9733
#
# Epoch 00014: val_accuracy improved from 0.96357 to 0.97326, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0617 - accuracy: 0.9807 - val_loss: 0.1094 - val_accuracy: 0.9624
#
# Epoch 00015: val_accuracy did not improve from 0.97326
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0598 - accuracy: 0.9786 - val_loss: 0.0889 - val_accuracy: 0.9709
#
# Epoch 00016: val_accuracy did not improve from 0.97326
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0452 - accuracy: 0.9860 - val_loss: 0.1065 - val_accuracy: 0.9655
#
# Epoch 00017: val_accuracy did not improve from 0.97326
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0398 - accuracy: 0.9861 - val_loss: 0.1075 - val_accuracy: 0.9636
#
# Epoch 00018: val_accuracy did not improve from 0.97326
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0410 - accuracy: 0.9869 - val_loss: 0.0657 - val_accuracy: 0.9760
#
# Epoch 00019: val_accuracy improved from 0.97326 to 0.97597, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0293 - accuracy: 0.9897 - val_loss: 0.0714 - val_accuracy: 0.9783
#
# Epoch 00020: val_accuracy improved from 0.97597 to 0.97829, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 21/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0334 - accuracy: 0.9889 - val_loss: 0.0767 - val_accuracy: 0.9764
#
# Epoch 00021: val_accuracy did not improve from 0.97829
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0231 - accuracy: 0.9933 - val_loss: 0.0769 - val_accuracy: 0.9764
#
# Epoch 00022: val_accuracy did not improve from 0.97829
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0202 - accuracy: 0.9936 - val_loss: 0.0773 - val_accuracy: 0.9760
#
# Epoch 00023: val_accuracy did not improve from 0.97829
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 0.0853 - val_accuracy: 0.9740
#
# Epoch 00024: val_accuracy did not improve from 0.97829
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 25/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0209 - accuracy: 0.9934 - val_loss: 0.0924 - val_accuracy: 0.9725
#
# Epoch 00025: val_accuracy did not improve from 0.97829
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0177 - accuracy: 0.9938 - val_loss: 0.0698 - val_accuracy: 0.9798
#
# Epoch 00026: val_accuracy improved from 0.97829 to 0.97984, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0148 - accuracy: 0.9949 - val_loss: 0.0928 - val_accuracy: 0.9698
#
# Epoch 00027: val_accuracy did not improve from 0.97984
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0176 - accuracy: 0.9936 - val_loss: 0.0654 - val_accuracy: 0.9787
#
# Epoch 00028: val_accuracy did not improve from 0.97984
# Epoch 29/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0128 - accuracy: 0.9957 - val_loss: 0.0754 - val_accuracy: 0.9740
#
# Epoch 00029: val_accuracy did not improve from 0.97984
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0139 - accuracy: 0.9950 - val_loss: 0.0646 - val_accuracy: 0.9791
#
# Epoch 00030: val_accuracy did not improve from 0.97984
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.0621 - val_accuracy: 0.9775
#
# Epoch 00031: val_accuracy did not improve from 0.97984
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0120 - accuracy: 0.9962 - val_loss: 0.0598 - val_accuracy: 0.9798
#
# Epoch 00032: val_accuracy did not improve from 0.97984
# Epoch 33/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0674 - val_accuracy: 0.9783
#
# Epoch 00033: val_accuracy did not improve from 0.97984
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.0624 - val_accuracy: 0.9775
#
# Epoch 00034: val_accuracy did not improve from 0.97984
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0115 - accuracy: 0.9957 - val_loss: 0.1891 - val_accuracy: 0.9473
#
# Epoch 00035: val_accuracy did not improve from 0.97984
# Epoch 36/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0138 - accuracy: 0.9961 - val_loss: 0.0754 - val_accuracy: 0.9767
#
# Epoch 00036: val_accuracy did not improve from 0.97984
# Epoch 37/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0082 - accuracy: 0.9981 - val_loss: 0.0722 - val_accuracy: 0.9779
#
# Epoch 00037: val_accuracy did not improve from 0.97984
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 38/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0725 - val_accuracy: 0.9771
#
# Epoch 00038: val_accuracy did not improve from 0.97984
# Epoch 39/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0067 - accuracy: 0.9980 - val_loss: 0.0608 - val_accuracy: 0.9802
#
# Epoch 00039: val_accuracy improved from 0.97984 to 0.98023, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 40/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0065 - accuracy: 0.9979 - val_loss: 0.0650 - val_accuracy: 0.9806
#
# Epoch 00040: val_accuracy improved from 0.98023 to 0.98062, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0083 - accuracy: 0.9975 - val_loss: 0.0739 - val_accuracy: 0.9779
#
# Epoch 00041: val_accuracy did not improve from 0.98062
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0690 - val_accuracy: 0.9810
#
# Epoch 00042: val_accuracy improved from 0.98062 to 0.98101, saving model to d:/temp/ensembles/model_V1_03\cp.ckpt
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0056 - accuracy: 0.9985 - val_loss: 0.0735 - val_accuracy: 0.9791
#
# Epoch 00043: val_accuracy did not improve from 0.98101
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0711 - val_accuracy: 0.9795
#
# Epoch 00044: val_accuracy did not improve from 0.98101
# Epoch 45/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0063 - accuracy: 0.9985 - val_loss: 0.0723 - val_accuracy: 0.9795
#
# Epoch 00045: val_accuracy did not improve from 0.98101
# Epoch 46/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0073 - accuracy: 0.9973 - val_loss: 0.0658 - val_accuracy: 0.9806
#
# Epoch 00046: val_accuracy did not improve from 0.98101
# Epoch 47/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.0816 - val_accuracy: 0.9767
#
# Epoch 00047: val_accuracy did not improve from 0.98101
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00047: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 15ms/step - loss: 2.8977 - accuracy: 0.2436 - val_loss: 2.4712 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8431 - accuracy: 0.4068 - val_loss: 2.4416 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.17442
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.0733 - accuracy: 0.6172 - val_loss: 1.7093 - val_accuracy: 0.4461
#
# Epoch 00003: val_accuracy improved from 0.17442 to 0.44612, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6203 - accuracy: 0.7885 - val_loss: 0.6820 - val_accuracy: 0.7341
#
# Epoch 00004: val_accuracy improved from 0.44612 to 0.73411, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.4197 - accuracy: 0.8594 - val_loss: 0.2806 - val_accuracy: 0.9116
#
# Epoch 00005: val_accuracy improved from 0.73411 to 0.91163, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3036 - accuracy: 0.8947 - val_loss: 0.1824 - val_accuracy: 0.9442
#
# Epoch 00006: val_accuracy improved from 0.91163 to 0.94419, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2285 - accuracy: 0.9237 - val_loss: 0.1436 - val_accuracy: 0.9512
#
# Epoch 00007: val_accuracy improved from 0.94419 to 0.95116, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1846 - accuracy: 0.9402 - val_loss: 0.1494 - val_accuracy: 0.9484
#
# Epoch 00008: val_accuracy did not improve from 0.95116
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1353 - accuracy: 0.9534 - val_loss: 0.1062 - val_accuracy: 0.9671
#
# Epoch 00009: val_accuracy improved from 0.95116 to 0.96705, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1084 - accuracy: 0.9638 - val_loss: 0.1345 - val_accuracy: 0.9566
#
# Epoch 00010: val_accuracy did not improve from 0.96705
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1072 - accuracy: 0.9664 - val_loss: 0.1247 - val_accuracy: 0.9612
#
# Epoch 00011: val_accuracy did not improve from 0.96705
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0847 - accuracy: 0.9694 - val_loss: 0.1186 - val_accuracy: 0.9616
#
# Epoch 00012: val_accuracy did not improve from 0.96705
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0691 - accuracy: 0.9779 - val_loss: 0.0854 - val_accuracy: 0.9694
#
# Epoch 00013: val_accuracy improved from 0.96705 to 0.96938, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0727 - accuracy: 0.9762 - val_loss: 0.0739 - val_accuracy: 0.9783
#
# Epoch 00014: val_accuracy improved from 0.96938 to 0.97829, saving model to d:/temp/ensembles/model_V1_04\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0568 - accuracy: 0.9814 - val_loss: 0.0910 - val_accuracy: 0.9690
#
# Epoch 00015: val_accuracy did not improve from 0.97829
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0615 - accuracy: 0.9785 - val_loss: 0.1101 - val_accuracy: 0.9647
#
# Epoch 00016: val_accuracy did not improve from 0.97829
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0491 - accuracy: 0.9852 - val_loss: 0.0883 - val_accuracy: 0.9705
#
# Epoch 00017: val_accuracy did not improve from 0.97829
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0396 - accuracy: 0.9870 - val_loss: 0.1175 - val_accuracy: 0.9601
#
# ...
#
# Epoch 00026: val_accuracy did not improve from 0.98140
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0205 - accuracy: 0.9931 - val_loss: 0.0596 - val_accuracy: 0.9791
#
# Epoch 00027: val_accuracy did not improve from 0.98140
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0246 - accuracy: 0.9918 - val_loss: 0.0858 - val_accuracy: 0.9736
#
# Epoch 00028: val_accuracy did not improve from 0.98140
# Epoch 29/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 0.0605 - val_accuracy: 0.9798
#
# Epoch 00029: val_accuracy did not improve from 0.98140
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 0.0643 - val_accuracy: 0.9798
#
# Epoch 00030: val_accuracy did not improve from 0.98140
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.0908 - val_accuracy: 0.9709
#
# Epoch 00031: val_accuracy did not improve from 0.98140
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0172 - accuracy: 0.9940 - val_loss: 0.1056 - val_accuracy: 0.9655
#
# Epoch 00032: val_accuracy did not improve from 0.98140
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 33/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0096 - accuracy: 0.9963 - val_loss: 0.0767 - val_accuracy: 0.9760
#
# Epoch 00033: val_accuracy did not improve from 0.98140
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 0.0649 - val_accuracy: 0.9822
#
# Epoch 00034: val_accuracy improved from 0.98140 to 0.98217, saving model to d:/temp/ensembles/model_V1_07\cp.ckpt
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0487 - val_accuracy: 0.9826
#
# Epoch 00035: val_accuracy improved from 0.98217 to 0.98256, saving model to d:/temp/ensembles/model_V1_07\cp.ckpt
# Epoch 36/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0822 - val_accuracy: 0.9764
#
# Epoch 00036: val_accuracy did not improve from 0.98256
# Epoch 37/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0079 - accuracy: 0.9967 - val_loss: 0.0632 - val_accuracy: 0.9826
#
# Epoch 00037: val_accuracy did not improve from 0.98256
# Epoch 38/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0556 - val_accuracy: 0.9810
#
# Epoch 00038: val_accuracy did not improve from 0.98256
# Epoch 39/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0086 - accuracy: 0.9969 - val_loss: 0.0502 - val_accuracy: 0.9841
#
# Epoch 00039: val_accuracy improved from 0.98256 to 0.98411, saving model to d:/temp/ensembles/model_V1_07\cp.ckpt
# Epoch 40/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0127 - accuracy: 0.9954 - val_loss: 0.0550 - val_accuracy: 0.9837
#
# Epoch 00040: val_accuracy did not improve from 0.98411
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0628 - val_accuracy: 0.9822
#
# Epoch 00041: val_accuracy did not improve from 0.98411
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0080 - accuracy: 0.9963 - val_loss: 0.0618 - val_accuracy: 0.9818
#
# Epoch 00042: val_accuracy did not improve from 0.98411
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0498 - val_accuracy: 0.9853
#
# Epoch 00043: val_accuracy improved from 0.98411 to 0.98527, saving model to d:/temp/ensembles/model_V1_07\cp.ckpt
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0576 - val_accuracy: 0.9841
#
# Epoch 00044: val_accuracy did not improve from 0.98527
# Epoch 45/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0572 - val_accuracy: 0.9833
#
# Epoch 00045: val_accuracy did not improve from 0.98527
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 46/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0591 - val_accuracy: 0.9837
#
# Epoch 00046: val_accuracy did not improve from 0.98527
# Epoch 47/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 0.0557 - val_accuracy: 0.9833
#
# Epoch 00047: val_accuracy did not improve from 0.98527
# Epoch 48/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0021 - accuracy: 0.9998 - val_loss: 0.0549 - val_accuracy: 0.9845
#
# Epoch 00048: val_accuracy did not improve from 0.98527
# Epoch 49/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.0593 - val_accuracy: 0.9833
#
# Epoch 00049: val_accuracy did not improve from 0.98527
# Epoch 50/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 0.0617 - val_accuracy: 0.9833
#
# Epoch 00050: val_accuracy did not improve from 0.98527
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00050: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 15ms/step - loss: 2.9730 - accuracy: 0.2309 - val_loss: 2.2460 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8226 - accuracy: 0.4125 - val_loss: 2.5749 - val_accuracy: 0.1752
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.17519, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.0217 - accuracy: 0.6460 - val_loss: 1.1709 - val_accuracy: 0.5341
#
# Epoch 00003: val_accuracy improved from 0.17519 to 0.53411, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6305 - accuracy: 0.7866 - val_loss: 0.3798 - val_accuracy: 0.8717
#
# Epoch 00004: val_accuracy improved from 0.53411 to 0.87171, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.4163 - accuracy: 0.8531 - val_loss: 0.2614 - val_accuracy: 0.9105
#
# Epoch 00005: val_accuracy improved from 0.87171 to 0.91047, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2816 - accuracy: 0.9044 - val_loss: 0.1806 - val_accuracy: 0.9407
#
# Epoch 00006: val_accuracy improved from 0.91047 to 0.94070, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2342 - accuracy: 0.9178 - val_loss: 0.1898 - val_accuracy: 0.9372
#
# Epoch 00007: val_accuracy did not improve from 0.94070
# Epoch 8/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1750 - accuracy: 0.9416 - val_loss: 0.1480 - val_accuracy: 0.9516
#
# Epoch 00008: val_accuracy improved from 0.94070 to 0.95155, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1514 - accuracy: 0.9491 - val_loss: 0.1119 - val_accuracy: 0.9647
#
# Epoch 00009: val_accuracy improved from 0.95155 to 0.96473, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1315 - accuracy: 0.9581 - val_loss: 0.1062 - val_accuracy: 0.9612
#
# Epoch 00010: val_accuracy did not improve from 0.96473
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0988 - accuracy: 0.9691 - val_loss: 0.1049 - val_accuracy: 0.9671
#
# Epoch 00011: val_accuracy improved from 0.96473 to 0.96705, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0852 - accuracy: 0.9722 - val_loss: 0.1018 - val_accuracy: 0.9686
#
# Epoch 00012: val_accuracy improved from 0.96705 to 0.96860, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0776 - accuracy: 0.9757 - val_loss: 0.0843 - val_accuracy: 0.9709
#
# Epoch 00013: val_accuracy improved from 0.96860 to 0.97093, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0786 - accuracy: 0.9758 - val_loss: 0.0800 - val_accuracy: 0.9748
#
# Epoch 00014: val_accuracy improved from 0.97093 to 0.97481, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0583 - accuracy: 0.9810 - val_loss: 0.1041 - val_accuracy: 0.9643
#
# Epoch 00015: val_accuracy did not improve from 0.97481
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0570 - accuracy: 0.9826 - val_loss: 0.0717 - val_accuracy: 0.9760
#
# Epoch 00016: val_accuracy improved from 0.97481 to 0.97597, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0483 - accuracy: 0.9836 - val_loss: 0.0696 - val_accuracy: 0.9775
#
# Epoch 00017: val_accuracy improved from 0.97597 to 0.97752, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0463 - accuracy: 0.9849 - val_loss: 0.0760 - val_accuracy: 0.9771
#
# Epoch 00018: val_accuracy did not improve from 0.97752
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0348 - accuracy: 0.9885 - val_loss: 0.1002 - val_accuracy: 0.9663
#
# Epoch 00019: val_accuracy did not improve from 0.97752
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0332 - accuracy: 0.9897 - val_loss: 0.0918 - val_accuracy: 0.9651
#
# Epoch 00020: val_accuracy did not improve from 0.97752
# Epoch 21/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0325 - accuracy: 0.9904 - val_loss: 0.0992 - val_accuracy: 0.9674
#
# Epoch 00021: val_accuracy did not improve from 0.97752
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0278 - accuracy: 0.9901 - val_loss: 0.0904 - val_accuracy: 0.9663
#
# Epoch 00022: val_accuracy did not improve from 0.97752
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.0517 - val_accuracy: 0.9822
#
# Epoch 00023: val_accuracy improved from 0.97752 to 0.98217, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0222 - accuracy: 0.9935 - val_loss: 0.0562 - val_accuracy: 0.9818
#
# Epoch 00024: val_accuracy did not improve from 0.98217
# Epoch 25/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0219 - accuracy: 0.9912 - val_loss: 0.0726 - val_accuracy: 0.9771
#
# Epoch 00025: val_accuracy did not improve from 0.98217
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0188 - accuracy: 0.9940 - val_loss: 0.0671 - val_accuracy: 0.9775
#
# Epoch 00026: val_accuracy did not improve from 0.98217
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.0560 - val_accuracy: 0.9818
#
# Epoch 00027: val_accuracy did not improve from 0.98217
# Epoch 28/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0182 - accuracy: 0.9945 - val_loss: 0.0418 - val_accuracy: 0.9845
#
# Epoch 00028: val_accuracy improved from 0.98217 to 0.98450, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 29/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0140 - accuracy: 0.9961 - val_loss: 0.0521 - val_accuracy: 0.9829
#
# Epoch 00029: val_accuracy did not improve from 0.98450
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0162 - accuracy: 0.9938 - val_loss: 0.0558 - val_accuracy: 0.9802
#
# Epoch 00030: val_accuracy did not improve from 0.98450
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0101 - accuracy: 0.9962 - val_loss: 0.0549 - val_accuracy: 0.9798
#
# Epoch 00031: val_accuracy did not improve from 0.98450
# Epoch 32/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0127 - accuracy: 0.9952 - val_loss: 0.0456 - val_accuracy: 0.9837
#
# Epoch 00032: val_accuracy did not improve from 0.98450
# Epoch 33/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0148 - accuracy: 0.9946 - val_loss: 0.0464 - val_accuracy: 0.9845
#
# Epoch 00033: val_accuracy did not improve from 0.98450
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0151 - accuracy: 0.9942 - val_loss: 0.0446 - val_accuracy: 0.9841
#
# Epoch 00034: val_accuracy did not improve from 0.98450
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0116 - accuracy: 0.9971 - val_loss: 0.0453 - val_accuracy: 0.9849
#
# Epoch 00035: val_accuracy improved from 0.98450 to 0.98488, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 36/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0118 - accuracy: 0.9966 - val_loss: 0.0472 - val_accuracy: 0.9837
#
# Epoch 00036: val_accuracy did not improve from 0.98488
# Epoch 37/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0561 - val_accuracy: 0.9826
#
# Epoch 00037: val_accuracy did not improve from 0.98488
# Epoch 38/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0102 - accuracy: 0.9959 - val_loss: 0.0478 - val_accuracy: 0.9845
#
# Epoch 00038: val_accuracy did not improve from 0.98488
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 39/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 0.0509 - val_accuracy: 0.9845
#
# Epoch 00039: val_accuracy did not improve from 0.98488
# Epoch 40/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0463 - val_accuracy: 0.9853
#
# Epoch 00040: val_accuracy improved from 0.98488 to 0.98527, saving model to d:/temp/ensembles/model_V1_08\cp.ckpt
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 0.0570 - val_accuracy: 0.9822
#
# Epoch 00041: val_accuracy did not improve from 0.98527
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0074 - accuracy: 0.9979 - val_loss: 0.0508 - val_accuracy: 0.9837
#
# Epoch 00042: val_accuracy did not improve from 0.98527
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0062 - accuracy: 0.9986 - val_loss: 0.0450 - val_accuracy: 0.9845
#
# Epoch 00043: val_accuracy did not improve from 0.98527
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00043: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-685-b70fc0eadd35> in <module>
#      25
#      26 file_path_prefix = f'd:/temp/ensembles/model_V1'
# ---> 27 modelsV1, histories_V1 = train_models(dataSolo, valset, file_path_prefix)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
def load_weights(models, file_path_prefix):

    for i in range(NUM_MODELS):

        file_path = f'{file_path_prefix}_{i:02}/cp.ckpt'

        models[i][0].load_weights(file_path)
        models[i][0].save('temp.hdf5')
        models[i][1].load_weights('temp.hdf5', by_name=True)
    

load_weights(models_V1, f'd:/temp/ensembles/model_V1')

# %% [markdown]
# ### Evaluate Models

# %%
def evaluate_models(models):
    
    accuracy = 0

    for i in range(NUM_MODELS):

        eval = models[i][0].evaluate(testset, verbose = 2)
        accuracy += eval[1]

    print(f'average accuracy: {(accuracy/NUM_MODELS)*100:.3f}')    


evaluate_models(models_V1)
# Out:
# 66/66 - 1s - loss: 0.0874 - accuracy: 0.9772
# 66/66 - 1s - loss: 0.0760 - accuracy: 0.9830
# 66/66 - 1s - loss: 0.0832 - accuracy: 0.9832
# 66/66 - 1s - loss: 0.0709 - accuracy: 0.9863
# 66/66 - 1s - loss: 0.0831 - accuracy: 0.9779
# 66/66 - 1s - loss: 0.0770 - accuracy: 0.9825
# 66/66 - 1s - loss: 0.0874 - accuracy: 0.9770
# 66/66 - 1s - loss: 0.0704 - accuracy: 0.9842
# 66/66 - 1s - loss: 0.0812 - accuracy: 0.9818
# average accuracy: 98.145

# %%
def get_labels_logits_and_preds(models):

    preds = [[] for _ in range(NUM_MODELS) ]
    logits = [[] for _ in range(NUM_MODELS)]
    labels = []
    for images, labs in testset.take(-1):

        labels.extend(labs.numpy())
        for i in range(NUM_MODELS):

            preds[i].extend(models[i][0].predict(images))
            logits[i].extend(models[i][1].predict(images))

    labels = [np.argmax(i) for i in labels]  
    
    return labels, logits, preds

labels_V1, logits_V1, preds_V1 = get_labels_logits_and_preds(models_V1)
# Out:
# WARNING:tensorflow:5 out of the last 2310 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9D74AE1F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 2311 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DABB81F8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 2312 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DABC4948> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 2313 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAC2F5E8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 2314 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DABB84C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 2315 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9D5BF7168> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 2316 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAC7EF78> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DACC5B88> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAC7EB88> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DABC4B88> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAE16828> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAE574C8> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DABC4558> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAF2C048> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000002B9DAF36318> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
def get_class_preds(preds):

    class_preds = []

    for i in range(test_dataset_length):

        c = []
        for m in range(NUM_MODELS):

            c.append(np.argmax(preds[m][i]))
        class_preds.append(c)
        
    return class_preds


class_preds_V1 = get_class_preds(preds_V1)

# %%
def get_class_from_sum_of_logits(logits):

    sum_logits = []

    for i in range(test_dataset_length):

        log = logits[0][i]
        for m in range(1, NUM_MODELS):
            log = np.add(log, logits[m][i])
        sum_logits.append(np.argmax(log))
    return(sum_logits)
    
class_logits_V1 = get_class_from_sum_of_logits(logits_V1)

# %%
def get_stats(labels, class_preds, class_logits):

    all_correct = 0
    all_incorrect = 0
    maj_vote = 0
    maj_wrong = 0
    tie = 0
    count = 0
    log_ok = 0
    log_ko = 0

    for k in range(test_dataset_length):

        counter = collections.Counter(class_preds[k])
        if len(counter) == 1:
            if counter.most_common(1)[0][0] == labels[k]:
                all_correct += 1
            else:
                all_incorrect += 1
        else:
            aux = counter.most_common(2)
            if aux[0][1] > aux[1][1] and aux[0][0] == labels[k]:
                maj_vote += 1
            if aux[0][1] > aux[1][1] and aux[0][0] != labels[k]:
                maj_wrong += 1
            elif aux[0][1] == aux[1][1]:
                tie += 1
        if class_logits[k] == labels[k]:
            log_ok += 1
        else:
            log_ko += 1
        count += 1 
        
    return [count, all_correct, all_incorrect, maj_vote, tie, maj_wrong, log_ok, log_ko]
    
    
res = get_stats(labels_V1, class_preds_V1, class_logits_V1)
print(res, res[6]/res[0])
# Out:
# [4170, 4008, 22, 94, 3, 43, 4108, 62] 0.9851318944844125

# %% [markdown]
# # Version II - dynamic data augmentation

# %% [markdown]
# ### Function to transform image

# %%
#https://www.tensorflow.org/api_docs/python/tf/image
#https://www.tensorflow.org/addons/api_docs/python/tfa/image

#pip install tensorflow-addons
import tensorflow_addons as tfa


def process_image(image, label):
    
    # random rotate 5 degrees
    r = tf.random.uniform(shape=(), minval=-0.175, maxval=0.175, dtype=tf.dtypes.float32)
    image = tfa.image.rotate(image, r)

    # translate image up to 10%
    rx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    ry = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32) 
    image = tfa.image.translate(image, [rx, ry])
   
    # change hue, saturation and value
    image = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.2, 0.4, 1.1, 0.4, 1.1),0,1)

    return image, label

# %%
dataV2 = dataset
dataV2 = dataV2.cache()
dataV2 = dataV2.shuffle(buffer_size = dataset_length)
dataV2 = dataV2.map(process_image)
dataV2 = dataV2.prefetch(buffer_size=10200)
dataV2 = dataV2.batch(batch_size=BATCH_SIZE)

# %%
file_path_prefix = f'd:/temp/ensembles/model_V2'    
models_V2, histories_V2 = train_models(dataV2, valset,file_path_prefix)
# Out:
# Epoch 1/100
# 160/160 [==============================] - 5s 16ms/step - loss: 3.1038 - accuracy: 0.2001 - val_loss: 2.4222 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.5842 - accuracy: 0.2289 - val_loss: 2.8165 - val_accuracy: 0.1795
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.17946, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.3481 - accuracy: 0.2467 - val_loss: 2.7960 - val_accuracy: 0.2066
#
# Epoch 00003: val_accuracy improved from 0.17946 to 0.20659, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.1611 - accuracy: 0.2881 - val_loss: 2.2553 - val_accuracy: 0.2143
#
# Epoch 00004: val_accuracy improved from 0.20659 to 0.21434, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8907 - accuracy: 0.3272 - val_loss: 1.8866 - val_accuracy: 0.3868
#
# Epoch 00005: val_accuracy improved from 0.21434 to 0.38682, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7531 - accuracy: 0.3702 - val_loss: 1.5088 - val_accuracy: 0.5023
#
# Epoch 00006: val_accuracy improved from 0.38682 to 0.50233, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.5614 - accuracy: 0.4419 - val_loss: 1.1061 - val_accuracy: 0.6271
#
# Epoch 00007: val_accuracy improved from 0.50233 to 0.62713, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.3537 - accuracy: 0.5145 - val_loss: 0.9172 - val_accuracy: 0.7256
#
# Epoch 00008: val_accuracy improved from 0.62713 to 0.72558, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 3s 17ms/step - loss: 1.1715 - accuracy: 0.5878 - val_loss: 0.5041 - val_accuracy: 0.8492
#
# Epoch 00009: val_accuracy improved from 0.72558 to 0.84922, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.9929 - accuracy: 0.6535 - val_loss: 0.5091 - val_accuracy: 0.8329
#
# Epoch 00010: val_accuracy did not improve from 0.84922
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.8215 - accuracy: 0.7090 - val_loss: 0.3687 - val_accuracy: 0.8822
#
# Epoch 00011: val_accuracy improved from 0.84922 to 0.88217, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.6704 - accuracy: 0.7643 - val_loss: 0.3339 - val_accuracy: 0.8833
#
# Epoch 00012: val_accuracy improved from 0.88217 to 0.88333, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.5431 - accuracy: 0.8173 - val_loss: 0.3880 - val_accuracy: 0.8775
#
# Epoch 00013: val_accuracy did not improve from 0.88333
# Epoch 14/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.4911 - accuracy: 0.8330 - val_loss: 0.1790 - val_accuracy: 0.9477
#
# Epoch 00014: val_accuracy improved from 0.88333 to 0.94767, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4047 - accuracy: 0.8657 - val_loss: 0.3975 - val_accuracy: 0.8926
#
# Epoch 00015: val_accuracy did not improve from 0.94767
# Epoch 16/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.3545 - accuracy: 0.8788 - val_loss: 0.1067 - val_accuracy: 0.9647
#
# Epoch 00016: val_accuracy improved from 0.94767 to 0.96473, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3012 - accuracy: 0.8921 - val_loss: 0.1446 - val_accuracy: 0.9512
#
# Epoch 00017: val_accuracy did not improve from 0.96473
# Epoch 18/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2708 - accuracy: 0.9119 - val_loss: 0.1894 - val_accuracy: 0.9508
#
# Epoch 00018: val_accuracy did not improve from 0.96473
# Epoch 19/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2397 - accuracy: 0.9148 - val_loss: 0.3017 - val_accuracy: 0.9256
#
# Epoch 00019: val_accuracy did not improve from 0.96473
# Epoch 20/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2096 - accuracy: 0.9236 - val_loss: 0.1044 - val_accuracy: 0.9624
#
# Epoch 00020: val_accuracy did not improve from 0.96473
# Epoch 21/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1824 - accuracy: 0.9419 - val_loss: 0.1176 - val_accuracy: 0.9624
#
# Epoch 00021: val_accuracy did not improve from 0.96473
# Epoch 22/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1685 - accuracy: 0.9420 - val_loss: 0.1522 - val_accuracy: 0.9554
#
# Epoch 00022: val_accuracy did not improve from 0.96473
# Epoch 23/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1653 - accuracy: 0.9454 - val_loss: 0.0599 - val_accuracy: 0.9798
#
# Epoch 00023: val_accuracy improved from 0.96473 to 0.97984, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 24/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1355 - accuracy: 0.9527 - val_loss: 0.0451 - val_accuracy: 0.9864
#
# Epoch 00024: val_accuracy improved from 0.97984 to 0.98643, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 25/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1165 - accuracy: 0.9576 - val_loss: 0.0468 - val_accuracy: 0.9857
#
# Epoch 00025: val_accuracy did not improve from 0.98643
# Epoch 26/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1268 - accuracy: 0.9551 - val_loss: 0.0511 - val_accuracy: 0.9826
#
# Epoch 00026: val_accuracy did not improve from 0.98643
# Epoch 27/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1130 - accuracy: 0.9626 - val_loss: 0.0596 - val_accuracy: 0.9787
#
# Epoch 00027: val_accuracy did not improve from 0.98643
# Epoch 28/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1141 - accuracy: 0.9603 - val_loss: 0.0266 - val_accuracy: 0.9915
#
# Epoch 00028: val_accuracy improved from 0.98643 to 0.99147, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 29/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1018 - accuracy: 0.9660 - val_loss: 0.0499 - val_accuracy: 0.9837
#
# Epoch 00029: val_accuracy did not improve from 0.99147
# Epoch 30/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0939 - accuracy: 0.9688 - val_loss: 0.0977 - val_accuracy: 0.9713
#
# Epoch 00030: val_accuracy did not improve from 0.99147
# Epoch 31/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0852 - accuracy: 0.9721 - val_loss: 0.0634 - val_accuracy: 0.9752
#
# Epoch 00031: val_accuracy did not improve from 0.99147
# Epoch 32/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0763 - accuracy: 0.9740 - val_loss: 0.0693 - val_accuracy: 0.9740
#
# Epoch 00032: val_accuracy did not improve from 0.99147
# Epoch 33/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0680 - accuracy: 0.9766 - val_loss: 0.0536 - val_accuracy: 0.9841
#
# Epoch 00033: val_accuracy did not improve from 0.99147
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 34/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0655 - accuracy: 0.9787 - val_loss: 0.0412 - val_accuracy: 0.9845
#
# Epoch 00034: val_accuracy did not improve from 0.99147
# Epoch 35/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0575 - accuracy: 0.9813 - val_loss: 0.0251 - val_accuracy: 0.9891
#
# Epoch 00035: val_accuracy did not improve from 0.99147
# Epoch 36/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0591 - accuracy: 0.9808 - val_loss: 0.0189 - val_accuracy: 0.9926
#
# Epoch 00036: val_accuracy improved from 0.99147 to 0.99264, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 37/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0649 - accuracy: 0.9801 - val_loss: 0.0415 - val_accuracy: 0.9833
#
# Epoch 00037: val_accuracy did not improve from 0.99264
# Epoch 38/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0565 - accuracy: 0.9815 - val_loss: 0.0155 - val_accuracy: 0.9950
#
# Epoch 00038: val_accuracy improved from 0.99264 to 0.99496, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 39/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0461 - accuracy: 0.9850 - val_loss: 0.0247 - val_accuracy: 0.9903
#
# Epoch 00039: val_accuracy did not improve from 0.99496
# Epoch 40/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0380 - accuracy: 0.9882 - val_loss: 0.0307 - val_accuracy: 0.9880
#
# Epoch 00040: val_accuracy did not improve from 0.99496
# Epoch 41/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0495 - accuracy: 0.9825 - val_loss: 0.0215 - val_accuracy: 0.9922
#
# Epoch 00041: val_accuracy did not improve from 0.99496
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0379 - accuracy: 0.9867 - val_loss: 0.0249 - val_accuracy: 0.9926
#
# Epoch 00042: val_accuracy did not improve from 0.99496
# Epoch 43/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0460 - accuracy: 0.9841 - val_loss: 0.0220 - val_accuracy: 0.9934
#
# Epoch 00043: val_accuracy did not improve from 0.99496
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 44/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0416 - accuracy: 0.9856 - val_loss: 0.0244 - val_accuracy: 0.9899
#
# Epoch 00044: val_accuracy did not improve from 0.99496
# Epoch 45/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0396 - accuracy: 0.9869 - val_loss: 0.0278 - val_accuracy: 0.9876
#
# Epoch 00045: val_accuracy did not improve from 0.99496
# Epoch 46/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0354 - accuracy: 0.9891 - val_loss: 0.0221 - val_accuracy: 0.9911
#
# Epoch 00046: val_accuracy did not improve from 0.99496
# Epoch 47/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0429 - accuracy: 0.9860 - val_loss: 0.0127 - val_accuracy: 0.9961
#
# Epoch 00047: val_accuracy improved from 0.99496 to 0.99612, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 48/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0344 - accuracy: 0.9895 - val_loss: 0.0197 - val_accuracy: 0.9919
#
# Epoch 00048: val_accuracy did not improve from 0.99612
# Epoch 49/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0333 - accuracy: 0.9892 - val_loss: 0.0163 - val_accuracy: 0.9942
#
# Epoch 00049: val_accuracy did not improve from 0.99612
# Epoch 50/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0335 - accuracy: 0.9888 - val_loss: 0.0118 - val_accuracy: 0.9946
#
# Epoch 00050: val_accuracy did not improve from 0.99612
# Epoch 51/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0319 - accuracy: 0.9903 - val_loss: 0.0215 - val_accuracy: 0.9911
#
# Epoch 00051: val_accuracy did not improve from 0.99612
# Epoch 52/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0388 - accuracy: 0.9863 - val_loss: 0.0343 - val_accuracy: 0.9880
#
# Epoch 00052: val_accuracy did not improve from 0.99612
# Epoch 53/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0357 - accuracy: 0.9891 - val_loss: 0.0169 - val_accuracy: 0.9934
#
# Epoch 00053: val_accuracy did not improve from 0.99612
# Epoch 54/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0242 - accuracy: 0.9919 - val_loss: 0.0165 - val_accuracy: 0.9926
#
# Epoch 00054: val_accuracy did not improve from 0.99612
# Epoch 55/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.0134 - val_accuracy: 0.9965
#
# Epoch 00055: val_accuracy improved from 0.99612 to 0.99651, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
#
# Epoch 00055: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 56/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0314 - accuracy: 0.9898 - val_loss: 0.0128 - val_accuracy: 0.9946
#
# Epoch 00056: val_accuracy did not improve from 0.99651
# Epoch 57/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 0.0117 - val_accuracy: 0.9969
#
# Epoch 00057: val_accuracy improved from 0.99651 to 0.99690, saving model to d:/temp/ensembles/model_V2_00\cp.ckpt
# Epoch 58/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.0113 - val_accuracy: 0.9953
#
# Epoch 00058: val_accuracy did not improve from 0.99690
# Epoch 59/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0208 - accuracy: 0.9937 - val_loss: 0.0188 - val_accuracy: 0.9942
#
# Epoch 00059: val_accuracy did not improve from 0.99690
# Epoch 60/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 0.0122 - val_accuracy: 0.9957
#
# Epoch 00060: val_accuracy did not improve from 0.99690
# Epoch 61/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0261 - accuracy: 0.9907 - val_loss: 0.0122 - val_accuracy: 0.9957
#
# Epoch 00061: val_accuracy did not improve from 0.99690
# Epoch 62/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 0.0159 - val_accuracy: 0.9934
#
# Epoch 00062: val_accuracy did not improve from 0.99690
# Epoch 63/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.0272 - val_accuracy: 0.9903
#
# Epoch 00063: val_accuracy did not improve from 0.99690
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 64/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0253 - accuracy: 0.9911 - val_loss: 0.0151 - val_accuracy: 0.9942
#
# Epoch 00064: val_accuracy did not improve from 0.99690
# Epoch 65/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0223 - accuracy: 0.9934 - val_loss: 0.0145 - val_accuracy: 0.9934
#
# Epoch 00065: val_accuracy did not improve from 0.99690
# Epoch 66/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0295 - accuracy: 0.9899 - val_loss: 0.0159 - val_accuracy: 0.9934
#
# Epoch 00066: val_accuracy did not improve from 0.99690
# Epoch 67/100
# 160/160 [==============================] - 3s 19ms/step - loss: 0.0223 - accuracy: 0.9917 - val_loss: 0.0144 - val_accuracy: 0.9938
#
# Epoch 00067: val_accuracy did not improve from 0.99690
# Epoch 68/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0255 - accuracy: 0.9913 - val_loss: 0.0156 - val_accuracy: 0.9942
#
# Epoch 00068: val_accuracy did not improve from 0.99690
#
# Epoch 00068: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 69/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0178 - accuracy: 0.9946 - val_loss: 0.0161 - val_accuracy: 0.9934
#
# Epoch 00069: val_accuracy did not improve from 0.99690
# Epoch 70/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0224 - accuracy: 0.9923 - val_loss: 0.0172 - val_accuracy: 0.9926
#
# Epoch 00070: val_accuracy did not improve from 0.99690
# Epoch 71/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.0151 - val_accuracy: 0.9938
#
# Epoch 00071: val_accuracy did not improve from 0.99690
# Epoch 72/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 0.0140 - val_accuracy: 0.9946
#
# Epoch 00072: val_accuracy did not improve from 0.99690
# Epoch 73/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0259 - accuracy: 0.9915 - val_loss: 0.0125 - val_accuracy: 0.9950
#
# Epoch 00073: val_accuracy did not improve from 0.99690
#
# Epoch 00073: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 00073: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 17ms/step - loss: 3.0370 - accuracy: 0.2065 - val_loss: 2.3939 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 2s 15ms/step - loss: 2.4974 - accuracy: 0.2435 - val_loss: 2.5363 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.17442
# Epoch 3/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.2822 - accuracy: 0.2717 - val_loss: 2.7444 - val_accuracy: 0.1946
#
# Epoch 00003: val_accuracy improved from 0.17442 to 0.19457, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.0249 - accuracy: 0.3110 - val_loss: 2.2348 - val_accuracy: 0.2519
#
# Epoch 00004: val_accuracy improved from 0.19457 to 0.25194, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.8739 - accuracy: 0.3362 - val_loss: 1.6354 - val_accuracy: 0.4643
#
# Epoch 00005: val_accuracy improved from 0.25194 to 0.46434, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7199 - accuracy: 0.3830 - val_loss: 1.3591 - val_accuracy: 0.5461
#
# Epoch 00006: val_accuracy improved from 0.46434 to 0.54612, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 3s 17ms/step - loss: 1.5474 - accuracy: 0.4514 - val_loss: 1.2080 - val_accuracy: 0.5826
#
# Epoch 00007: val_accuracy improved from 0.54612 to 0.58256, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.3539 - accuracy: 0.5087 - val_loss: 0.8637 - val_accuracy: 0.7337
#
# Epoch 00008: val_accuracy improved from 0.58256 to 0.73372, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.1301 - accuracy: 0.6004 - val_loss: 0.4630 - val_accuracy: 0.8473
#
# Epoch 00009: val_accuracy improved from 0.73372 to 0.84729, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.8914 - accuracy: 0.6911 - val_loss: 0.3419 - val_accuracy: 0.8826
#
# Epoch 00010: val_accuracy improved from 0.84729 to 0.88256, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.7382 - accuracy: 0.7415 - val_loss: 0.3963 - val_accuracy: 0.8589
#
# Epoch 00011: val_accuracy did not improve from 0.88256
# Epoch 12/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.6200 - accuracy: 0.7792 - val_loss: 0.2613 - val_accuracy: 0.9155
#
# Epoch 00012: val_accuracy improved from 0.88256 to 0.91550, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.5283 - accuracy: 0.8190 - val_loss: 0.1581 - val_accuracy: 0.9434
#
# Epoch 00013: val_accuracy improved from 0.91550 to 0.94341, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4511 - accuracy: 0.8446 - val_loss: 0.2019 - val_accuracy: 0.9391
#
# Epoch 00014: val_accuracy did not improve from 0.94341
# Epoch 15/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3808 - accuracy: 0.8686 - val_loss: 0.1096 - val_accuracy: 0.9620
#
# Epoch 00015: val_accuracy improved from 0.94341 to 0.96202, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 16/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3244 - accuracy: 0.8893 - val_loss: 0.1288 - val_accuracy: 0.9566
#
# Epoch 00016: val_accuracy did not improve from 0.96202
# Epoch 17/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3094 - accuracy: 0.8969 - val_loss: 0.2197 - val_accuracy: 0.9411
#
# Epoch 00017: val_accuracy did not improve from 0.96202
# Epoch 18/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2530 - accuracy: 0.9148 - val_loss: 0.1079 - val_accuracy: 0.9554
#
# Epoch 00018: val_accuracy did not improve from 0.96202
# Epoch 19/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2331 - accuracy: 0.9204 - val_loss: 0.1158 - val_accuracy: 0.9655
#
# Epoch 00019: val_accuracy improved from 0.96202 to 0.96550, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 20/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2159 - accuracy: 0.9263 - val_loss: 0.1512 - val_accuracy: 0.9461
#
# Epoch 00020: val_accuracy did not improve from 0.96550
# Epoch 21/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1846 - accuracy: 0.9371 - val_loss: 0.1161 - val_accuracy: 0.9593
#
# Epoch 00021: val_accuracy did not improve from 0.96550
# Epoch 22/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1717 - accuracy: 0.9398 - val_loss: 0.1301 - val_accuracy: 0.9593
#
# Epoch 00022: val_accuracy did not improve from 0.96550
# Epoch 23/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1601 - accuracy: 0.9436 - val_loss: 0.0600 - val_accuracy: 0.9787
#
# Epoch 00023: val_accuracy improved from 0.96550 to 0.97868, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 24/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1379 - accuracy: 0.9534 - val_loss: 0.0949 - val_accuracy: 0.9632
#
# Epoch 00024: val_accuracy did not improve from 0.97868
# Epoch 25/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1287 - accuracy: 0.9590 - val_loss: 0.0583 - val_accuracy: 0.9806
#
# Epoch 00025: val_accuracy improved from 0.97868 to 0.98062, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 26/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1163 - accuracy: 0.9599 - val_loss: 0.0775 - val_accuracy: 0.9756
#
# Epoch 00026: val_accuracy did not improve from 0.98062
# Epoch 27/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1148 - accuracy: 0.9617 - val_loss: 0.0326 - val_accuracy: 0.9895
#
# Epoch 00027: val_accuracy improved from 0.98062 to 0.98953, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 28/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1087 - accuracy: 0.9635 - val_loss: 0.0594 - val_accuracy: 0.9791
#
# Epoch 00028: val_accuracy did not improve from 0.98953
# Epoch 29/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1016 - accuracy: 0.9656 - val_loss: 0.0417 - val_accuracy: 0.9841
#
# Epoch 00029: val_accuracy did not improve from 0.98953
# Epoch 30/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1003 - accuracy: 0.9681 - val_loss: 0.0883 - val_accuracy: 0.9764
#
# Epoch 00030: val_accuracy did not improve from 0.98953
# Epoch 31/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0782 - accuracy: 0.9729 - val_loss: 0.0901 - val_accuracy: 0.9709
#
# Epoch 00031: val_accuracy did not improve from 0.98953
# Epoch 32/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0883 - accuracy: 0.9725 - val_loss: 0.0646 - val_accuracy: 0.9752
#
# Epoch 00032: val_accuracy did not improve from 0.98953
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 33/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0733 - accuracy: 0.9756 - val_loss: 0.0281 - val_accuracy: 0.9907
#
# Epoch 00033: val_accuracy improved from 0.98953 to 0.99070, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 34/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0639 - accuracy: 0.9777 - val_loss: 0.0337 - val_accuracy: 0.9864
#
# Epoch 00034: val_accuracy did not improve from 0.99070
# Epoch 35/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0630 - accuracy: 0.9794 - val_loss: 0.0150 - val_accuracy: 0.9957
#
# Epoch 00035: val_accuracy improved from 0.99070 to 0.99574, saving model to d:/temp/ensembles/model_V2_01\cp.ckpt
# Epoch 36/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0537 - accuracy: 0.9826 - val_loss: 0.0499 - val_accuracy: 0.9849
#
# Epoch 00036: val_accuracy did not improve from 0.99574
# Epoch 37/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0541 - accuracy: 0.9805 - val_loss: 0.0252 - val_accuracy: 0.9911
#
# Epoch 00037: val_accuracy did not improve from 0.99574
# Epoch 38/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0561 - accuracy: 0.9803 - val_loss: 0.0317 - val_accuracy: 0.9911
#
# Epoch 00038: val_accuracy did not improve from 0.99574
# Epoch 39/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0458 - accuracy: 0.9864 - val_loss: 0.0489 - val_accuracy: 0.9802
#
# Epoch 00039: val_accuracy did not improve from 0.99574
# Epoch 40/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0441 - accuracy: 0.9853 - val_loss: 0.0320 - val_accuracy: 0.9860
#
# Epoch 00040: val_accuracy did not improve from 0.99574
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 41/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0509 - accuracy: 0.9823 - val_loss: 0.0242 - val_accuracy: 0.9903
#
# Epoch 00041: val_accuracy did not improve from 0.99574
# Epoch 42/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0547 - accuracy: 0.9836 - val_loss: 0.0430 - val_accuracy: 0.9826
#
# Epoch 00042: val_accuracy did not improve from 0.99574
# Epoch 43/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0398 - accuracy: 0.9869 - val_loss: 0.0202 - val_accuracy: 0.9953
#
# Epoch 00043: val_accuracy did not improve from 0.99574
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0434 - accuracy: 0.9851 - val_loss: 0.0202 - val_accuracy: 0.9895
#
# Epoch 00044: val_accuracy did not improve from 0.99574
# Epoch 45/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0407 - accuracy: 0.9869 - val_loss: 0.0203 - val_accuracy: 0.9938
#
# Epoch 00045: val_accuracy did not improve from 0.99574
#
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 46/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0391 - accuracy: 0.9875 - val_loss: 0.0154 - val_accuracy: 0.9950
#
# Epoch 00046: val_accuracy did not improve from 0.99574
# Epoch 47/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0402 - accuracy: 0.9877 - val_loss: 0.0245 - val_accuracy: 0.9915
#
# Epoch 00047: val_accuracy did not improve from 0.99574
# Epoch 48/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0383 - accuracy: 0.9853 - val_loss: 0.0183 - val_accuracy: 0.9919
#
# Epoch 00048: val_accuracy did not improve from 0.99574
# Epoch 49/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0327 - accuracy: 0.9887 - val_loss: 0.0149 - val_accuracy: 0.9946
#
# Epoch 00049: val_accuracy did not improve from 0.99574
# Epoch 50/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0374 - accuracy: 0.9864 - val_loss: 0.0218 - val_accuracy: 0.9915
#
# Epoch 00050: val_accuracy did not improve from 0.99574
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00050: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 17ms/step - loss: 3.2062 - accuracy: 0.1868 - val_loss: 2.3921 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.5763 - accuracy: 0.2412 - val_loss: 3.2312 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.17442
# Epoch 3/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.3759 - accuracy: 0.2759 - val_loss: 2.9241 - val_accuracy: 0.1880
#
# Epoch 00003: val_accuracy improved from 0.17442 to 0.18798, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.0276 - accuracy: 0.3035 - val_loss: 2.1700 - val_accuracy: 0.2279
#
# Epoch 00004: val_accuracy improved from 0.18798 to 0.22791, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8620 - accuracy: 0.3457 - val_loss: 1.8311 - val_accuracy: 0.3326
#
# Epoch 00005: val_accuracy improved from 0.22791 to 0.33256, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7049 - accuracy: 0.3937 - val_loss: 1.4517 - val_accuracy: 0.4748
#
# Epoch 00006: val_accuracy improved from 0.33256 to 0.47481, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.5165 - accuracy: 0.4609 - val_loss: 0.9246 - val_accuracy: 0.6946
#
# Epoch 00007: val_accuracy improved from 0.47481 to 0.69457, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.2900 - accuracy: 0.5463 - val_loss: 0.8363 - val_accuracy: 0.7194
#
# Epoch 00008: val_accuracy improved from 0.69457 to 0.71938, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.0534 - accuracy: 0.6201 - val_loss: 0.3985 - val_accuracy: 0.8640
#
# Epoch 00009: val_accuracy improved from 0.71938 to 0.86395, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.9053 - accuracy: 0.6899 - val_loss: 0.3783 - val_accuracy: 0.8705
#
# Epoch 00010: val_accuracy improved from 0.86395 to 0.87054, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.7179 - accuracy: 0.7515 - val_loss: 0.3095 - val_accuracy: 0.9023
#
# Epoch 00011: val_accuracy improved from 0.87054 to 0.90233, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.6228 - accuracy: 0.7899 - val_loss: 0.3637 - val_accuracy: 0.8841
#
# Epoch 00012: val_accuracy did not improve from 0.90233
# Epoch 13/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.5033 - accuracy: 0.8292 - val_loss: 0.2588 - val_accuracy: 0.9147
#
# Epoch 00013: val_accuracy improved from 0.90233 to 0.91473, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4298 - accuracy: 0.8505 - val_loss: 0.2068 - val_accuracy: 0.9337
#
# Epoch 00014: val_accuracy improved from 0.91473 to 0.93372, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4056 - accuracy: 0.8637 - val_loss: 0.1922 - val_accuracy: 0.9388
#
# Epoch 00015: val_accuracy improved from 0.93372 to 0.93876, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 16/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3566 - accuracy: 0.8808 - val_loss: 0.0994 - val_accuracy: 0.9655
#
# Epoch 00016: val_accuracy improved from 0.93876 to 0.96550, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2969 - accuracy: 0.8975 - val_loss: 0.1138 - val_accuracy: 0.9531
#
# Epoch 00017: val_accuracy did not improve from 0.96550
# Epoch 18/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2378 - accuracy: 0.9207 - val_loss: 0.1465 - val_accuracy: 0.9496
#
# Epoch 00018: val_accuracy did not improve from 0.96550
# Epoch 19/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2239 - accuracy: 0.9237 - val_loss: 0.1403 - val_accuracy: 0.9562
#
# Epoch 00019: val_accuracy did not improve from 0.96550
# Epoch 20/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2045 - accuracy: 0.9331 - val_loss: 0.1357 - val_accuracy: 0.9609
#
# Epoch 00020: val_accuracy did not improve from 0.96550
# Epoch 21/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1750 - accuracy: 0.9399 - val_loss: 0.1294 - val_accuracy: 0.9566
#
# Epoch 00021: val_accuracy did not improve from 0.96550
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 22/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1438 - accuracy: 0.9509 - val_loss: 0.0632 - val_accuracy: 0.9771
#
# Epoch 00022: val_accuracy improved from 0.96550 to 0.97713, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 23/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1301 - accuracy: 0.9565 - val_loss: 0.0646 - val_accuracy: 0.9764
#
# Epoch 00023: val_accuracy did not improve from 0.97713
# Epoch 24/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1357 - accuracy: 0.9547 - val_loss: 0.0716 - val_accuracy: 0.9729
#
# Epoch 00024: val_accuracy did not improve from 0.97713
# Epoch 25/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1358 - accuracy: 0.9572 - val_loss: 0.0496 - val_accuracy: 0.9818
#
# Epoch 00025: val_accuracy improved from 0.97713 to 0.98178, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 26/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1221 - accuracy: 0.9604 - val_loss: 0.0613 - val_accuracy: 0.9802
#
# Epoch 00026: val_accuracy did not improve from 0.98178
# Epoch 27/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1045 - accuracy: 0.9634 - val_loss: 0.0653 - val_accuracy: 0.9791
#
# Epoch 00027: val_accuracy did not improve from 0.98178
# Epoch 28/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1238 - accuracy: 0.9612 - val_loss: 0.0869 - val_accuracy: 0.9721
#
# Epoch 00028: val_accuracy did not improve from 0.98178
# Epoch 29/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1147 - accuracy: 0.9602 - val_loss: 0.0782 - val_accuracy: 0.9744
#
# Epoch 00029: val_accuracy did not improve from 0.98178
# Epoch 30/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.1094 - accuracy: 0.9635 - val_loss: 0.0920 - val_accuracy: 0.9733
#
# Epoch 00030: val_accuracy did not improve from 0.98178
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 31/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0887 - accuracy: 0.9677 - val_loss: 0.0625 - val_accuracy: 0.9829
#
# Epoch 00031: val_accuracy improved from 0.98178 to 0.98295, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 32/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0903 - accuracy: 0.9693 - val_loss: 0.0929 - val_accuracy: 0.9752
#
# Epoch 00032: val_accuracy did not improve from 0.98295
# Epoch 33/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0847 - accuracy: 0.9707 - val_loss: 0.0601 - val_accuracy: 0.9791
#
# Epoch 00033: val_accuracy did not improve from 0.98295
# Epoch 34/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0735 - accuracy: 0.9767 - val_loss: 0.0387 - val_accuracy: 0.9880
#
# Epoch 00034: val_accuracy improved from 0.98295 to 0.98798, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 35/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0718 - accuracy: 0.9748 - val_loss: 0.0453 - val_accuracy: 0.9853
#
# Epoch 00035: val_accuracy did not improve from 0.98798
# Epoch 36/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0708 - accuracy: 0.9749 - val_loss: 0.0405 - val_accuracy: 0.9864
#
# Epoch 00036: val_accuracy did not improve from 0.98798
# Epoch 37/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0699 - accuracy: 0.9762 - val_loss: 0.0420 - val_accuracy: 0.9849
#
# Epoch 00037: val_accuracy did not improve from 0.98798
# Epoch 38/100
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0748 - accuracy: 0.9742 - val_loss: 0.0417 - val_accuracy: 0.9826
#
# Epoch 00038: val_accuracy did not improve from 0.98798
# Epoch 39/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0665 - accuracy: 0.9776 - val_loss: 0.0572 - val_accuracy: 0.9783
#
# Epoch 00039: val_accuracy did not improve from 0.98798
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 40/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0633 - accuracy: 0.9801 - val_loss: 0.0409 - val_accuracy: 0.9860
#
# Epoch 00040: val_accuracy did not improve from 0.98798
# Epoch 41/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0681 - accuracy: 0.9745 - val_loss: 0.0532 - val_accuracy: 0.9798
#
# Epoch 00041: val_accuracy did not improve from 0.98798
# Epoch 42/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0648 - accuracy: 0.9807 - val_loss: 0.0388 - val_accuracy: 0.9880
#
# Epoch 00042: val_accuracy did not improve from 0.98798
# Epoch 43/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0539 - accuracy: 0.9829 - val_loss: 0.0477 - val_accuracy: 0.9826
#
# Epoch 00043: val_accuracy did not improve from 0.98798
# Epoch 44/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0631 - accuracy: 0.9778 - val_loss: 0.0390 - val_accuracy: 0.9884
#
# Epoch 00044: val_accuracy improved from 0.98798 to 0.98837, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 45/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0562 - accuracy: 0.9802 - val_loss: 0.0385 - val_accuracy: 0.9888
#
# Epoch 00045: val_accuracy improved from 0.98837 to 0.98876, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 46/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0498 - accuracy: 0.9829 - val_loss: 0.0303 - val_accuracy: 0.9899
#
# Epoch 00046: val_accuracy improved from 0.98876 to 0.98992, saving model to d:/temp/ensembles/model_V2_02\cp.ckpt
# Epoch 47/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0645 - accuracy: 0.9760 - val_loss: 0.0329 - val_accuracy: 0.9895
#
# Epoch 00047: val_accuracy did not improve from 0.98992
# Epoch 48/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0520 - accuracy: 0.9823 - val_loss: 0.0332 - val_accuracy: 0.9891
#
# Epoch 00048: val_accuracy did not improve from 0.98992
# Epoch 49/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0593 - accuracy: 0.9807 - val_loss: 0.0366 - val_accuracy: 0.9880
#
# Epoch 00049: val_accuracy did not improve from 0.98992
# Epoch 50/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0520 - accuracy: 0.9814 - val_loss: 0.0391 - val_accuracy: 0.9884
#
# Epoch 00050: val_accuracy did not improve from 0.98992
# Epoch 51/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0508 - accuracy: 0.9825 - val_loss: 0.0367 - val_accuracy: 0.9880
#
# Epoch 00051: val_accuracy did not improve from 0.98992
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 52/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0609 - accuracy: 0.9792 - val_loss: 0.0345 - val_accuracy: 0.9895
#
# Epoch 00052: val_accuracy did not improve from 0.98992
# Epoch 53/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0558 - accuracy: 0.9797 - val_loss: 0.0352 - val_accuracy: 0.9888
#
# Epoch 00053: val_accuracy did not improve from 0.98992
# Epoch 54/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0486 - accuracy: 0.9840 - val_loss: 0.0333 - val_accuracy: 0.9891
#
# Epoch 00054: val_accuracy did not improve from 0.98992
# Epoch 55/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0593 - accuracy: 0.9820 - val_loss: 0.0362 - val_accuracy: 0.9884
#
# Epoch 00055: val_accuracy did not improve from 0.98992
# Epoch 56/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0573 - accuracy: 0.9846 - val_loss: 0.0359 - val_accuracy: 0.9884
#
# Epoch 00056: val_accuracy did not improve from 0.98992
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 57/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0553 - accuracy: 0.9807 - val_loss: 0.0324 - val_accuracy: 0.9895
#
# Epoch 00057: val_accuracy did not improve from 0.98992
# Epoch 58/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0441 - accuracy: 0.9863 - val_loss: 0.0320 - val_accuracy: 0.9899
#
# Epoch 00058: val_accuracy did not improve from 0.98992
# Epoch 59/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0451 - accuracy: 0.9851 - val_loss: 0.0320 - val_accuracy: 0.9895
#
# Epoch 00059: val_accuracy did not improve from 0.98992
# Epoch 60/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0430 - accuracy: 0.9850 - val_loss: 0.0330 - val_accuracy: 0.9895
#
# Epoch 00060: val_accuracy did not improve from 0.98992
# Epoch 61/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0457 - accuracy: 0.9839 - val_loss: 0.0316 - val_accuracy: 0.9891
#
# Epoch 00061: val_accuracy did not improve from 0.98992
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 00061: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 17ms/step - loss: 3.1380 - accuracy: 0.1974 - val_loss: 2.4797 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.5976 - accuracy: 0.2460 - val_loss: 2.3861 - val_accuracy: 0.1760
#
# Epoch 00002: val_accuracy improved from 0.17442 to 0.17597, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 3/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.3179 - accuracy: 0.2698 - val_loss: 2.1457 - val_accuracy: 0.2760
#
# Epoch 00003: val_accuracy improved from 0.17597 to 0.27597, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.0337 - accuracy: 0.2966 - val_loss: 1.9483 - val_accuracy: 0.3143
#
# Epoch 00004: val_accuracy improved from 0.27597 to 0.31434, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.8761 - accuracy: 0.3422 - val_loss: 1.6617 - val_accuracy: 0.4167
#
# Epoch 00005: val_accuracy improved from 0.31434 to 0.41667, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7287 - accuracy: 0.3725 - val_loss: 1.4769 - val_accuracy: 0.5019
#
# Epoch 00006: val_accuracy improved from 0.41667 to 0.50194, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.5589 - accuracy: 0.4477 - val_loss: 1.1255 - val_accuracy: 0.6302
#
# Epoch 00007: val_accuracy improved from 0.50194 to 0.63023, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.3654 - accuracy: 0.5116 - val_loss: 1.0291 - val_accuracy: 0.6426
#
# Epoch 00008: val_accuracy improved from 0.63023 to 0.64264, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.1786 - accuracy: 0.5774 - val_loss: 0.6292 - val_accuracy: 0.7826
#
# Epoch 00009: val_accuracy improved from 0.64264 to 0.78256, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.0217 - accuracy: 0.6425 - val_loss: 0.4198 - val_accuracy: 0.8597
#
# Epoch 00010: val_accuracy improved from 0.78256 to 0.85969, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.8378 - accuracy: 0.7073 - val_loss: 0.3422 - val_accuracy: 0.8818
#
# Epoch 00011: val_accuracy improved from 0.85969 to 0.88178, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 12/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.7030 - accuracy: 0.7566 - val_loss: 0.2309 - val_accuracy: 0.9213
#
# Epoch 00012: val_accuracy improved from 0.88178 to 0.92132, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.5689 - accuracy: 0.8046 - val_loss: 0.1985 - val_accuracy: 0.9291
#
# Epoch 00013: val_accuracy improved from 0.92132 to 0.92907, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4948 - accuracy: 0.8292 - val_loss: 0.2414 - val_accuracy: 0.9306
#
# Epoch 00014: val_accuracy improved from 0.92907 to 0.93062, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4242 - accuracy: 0.8567 - val_loss: 0.1762 - val_accuracy: 0.9419
#
# Epoch 00015: val_accuracy improved from 0.93062 to 0.94186, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 16/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3510 - accuracy: 0.8789 - val_loss: 0.1483 - val_accuracy: 0.9492
#
# Epoch 00016: val_accuracy improved from 0.94186 to 0.94922, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 17/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3153 - accuracy: 0.8928 - val_loss: 0.2513 - val_accuracy: 0.9236
#
# Epoch 00017: val_accuracy did not improve from 0.94922
# Epoch 18/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2657 - accuracy: 0.9098 - val_loss: 0.1142 - val_accuracy: 0.9620
#
# Epoch 00018: val_accuracy improved from 0.94922 to 0.96202, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 19/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2431 - accuracy: 0.9224 - val_loss: 0.1385 - val_accuracy: 0.9543
#
# Epoch 00019: val_accuracy did not improve from 0.96202
# Epoch 20/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2161 - accuracy: 0.9253 - val_loss: 0.1365 - val_accuracy: 0.9578
#
# Epoch 00020: val_accuracy did not improve from 0.96202
# Epoch 21/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2013 - accuracy: 0.9323 - val_loss: 0.1382 - val_accuracy: 0.9477
#
# Epoch 00021: val_accuracy did not improve from 0.96202
# Epoch 22/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1866 - accuracy: 0.9418 - val_loss: 0.1068 - val_accuracy: 0.9632
#
# Epoch 00022: val_accuracy improved from 0.96202 to 0.96318, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 23/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1527 - accuracy: 0.9490 - val_loss: 0.0615 - val_accuracy: 0.9795
#
# Epoch 00023: val_accuracy improved from 0.96318 to 0.97946, saving model to d:/temp/ensembles/model_V2_03\cp.ckpt
# Epoch 24/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1341 - accuracy: 0.9554 - val_loss: 0.0618 - val_accuracy: 0.9783
#
# Epoch 00024: val_accuracy did not improve from 0.97946
# Epoch 25/100
# ...
# Epoch 00084: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 85/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0292 - accuracy: 0.9920 - val_loss: 0.0189 - val_accuracy: 0.9934
#
# Epoch 00085: val_accuracy did not improve from 0.99419
# Epoch 86/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0265 - accuracy: 0.9903 - val_loss: 0.0184 - val_accuracy: 0.9938
#
# Epoch 00086: val_accuracy did not improve from 0.99419
# Epoch 87/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0270 - accuracy: 0.9916 - val_loss: 0.0186 - val_accuracy: 0.9934
#
# Epoch 00087: val_accuracy did not improve from 0.99419
# Epoch 88/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0235 - accuracy: 0.9927 - val_loss: 0.0183 - val_accuracy: 0.9938
#
# Epoch 00088: val_accuracy did not improve from 0.99419
# Epoch 89/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0232 - accuracy: 0.9923 - val_loss: 0.0178 - val_accuracy: 0.9938
#
# Epoch 00089: val_accuracy did not improve from 0.99419
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 90/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0278 - accuracy: 0.9921 - val_loss: 0.0182 - val_accuracy: 0.9942
#
# Epoch 00090: val_accuracy did not improve from 0.99419
# Epoch 91/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0243 - accuracy: 0.9918 - val_loss: 0.0176 - val_accuracy: 0.9938
#
# Epoch 00091: val_accuracy did not improve from 0.99419
# Epoch 92/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.0179 - val_accuracy: 0.9934
#
# Epoch 00092: val_accuracy did not improve from 0.99419
# Epoch 93/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.0182 - val_accuracy: 0.9938
#
# Epoch 00093: val_accuracy did not improve from 0.99419
# Epoch 94/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0184 - val_accuracy: 0.9938
#
# Epoch 00094: val_accuracy did not improve from 0.99419
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 00094: early stopping
# Epoch 1/100
# 160/160 [==============================] - 3s 17ms/step - loss: 3.1288 - accuracy: 0.1989 - val_loss: 2.4830 - val_accuracy: 0.1744
#
# Epoch 00001: val_accuracy improved from -inf to 0.17442, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 2/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.6164 - accuracy: 0.2362 - val_loss: 2.8837 - val_accuracy: 0.1744
#
# Epoch 00002: val_accuracy did not improve from 0.17442
# Epoch 3/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.3774 - accuracy: 0.2666 - val_loss: 2.7944 - val_accuracy: 0.1798
#
# Epoch 00003: val_accuracy improved from 0.17442 to 0.17984, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 4/100
# 160/160 [==============================] - 3s 16ms/step - loss: 2.0750 - accuracy: 0.3091 - val_loss: 2.4166 - val_accuracy: 0.2182
#
# Epoch 00004: val_accuracy improved from 0.17984 to 0.21822, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 5/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.9145 - accuracy: 0.3249 - val_loss: 1.5880 - val_accuracy: 0.4740
#
# Epoch 00005: val_accuracy improved from 0.21822 to 0.47403, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 6/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.7065 - accuracy: 0.3927 - val_loss: 1.3001 - val_accuracy: 0.5484
#
# Epoch 00006: val_accuracy improved from 0.47403 to 0.54845, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 7/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.5103 - accuracy: 0.4656 - val_loss: 0.9990 - val_accuracy: 0.6570
#
# Epoch 00007: val_accuracy improved from 0.54845 to 0.65698, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 8/100
# 160/160 [==============================] - 3s 16ms/step - loss: 1.2748 - accuracy: 0.5393 - val_loss: 0.8387 - val_accuracy: 0.7570
#
# Epoch 00008: val_accuracy improved from 0.65698 to 0.75698, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 9/100
# 160/160 [==============================] - 2s 15ms/step - loss: 1.1103 - accuracy: 0.6023 - val_loss: 0.4642 - val_accuracy: 0.8508
#
# Epoch 00009: val_accuracy improved from 0.75698 to 0.85078, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 10/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.9206 - accuracy: 0.6788 - val_loss: 0.3693 - val_accuracy: 0.8717
#
# Epoch 00010: val_accuracy improved from 0.85078 to 0.87171, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 11/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.7440 - accuracy: 0.7399 - val_loss: 0.3834 - val_accuracy: 0.8705
#
# Epoch 00011: val_accuracy did not improve from 0.87171
# Epoch 12/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.6450 - accuracy: 0.7816 - val_loss: 0.2663 - val_accuracy: 0.9128
#
# Epoch 00012: val_accuracy improved from 0.87171 to 0.91279, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 13/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.5406 - accuracy: 0.8171 - val_loss: 0.2234 - val_accuracy: 0.9264
#
# Epoch 00013: val_accuracy improved from 0.91279 to 0.92636, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 14/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.4533 - accuracy: 0.8449 - val_loss: 0.1878 - val_accuracy: 0.9295
#
# Epoch 00014: val_accuracy improved from 0.92636 to 0.92946, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 15/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3690 - accuracy: 0.8775 - val_loss: 0.1076 - val_accuracy: 0.9655
#
# Epoch 00015: val_accuracy improved from 0.92946 to 0.96550, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 16/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.3459 - accuracy: 0.8834 - val_loss: 0.1311 - val_accuracy: 0.9547
#
# Epoch 00016: val_accuracy did not improve from 0.96550
# Epoch 17/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2757 - accuracy: 0.9052 - val_loss: 0.2208 - val_accuracy: 0.9430
#
# Epoch 00017: val_accuracy did not improve from 0.96550
# Epoch 18/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.2502 - accuracy: 0.9173 - val_loss: 0.2871 - val_accuracy: 0.9248
#
# Epoch 00018: val_accuracy did not improve from 0.96550
# Epoch 19/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.2323 - accuracy: 0.9192 - val_loss: 0.1428 - val_accuracy: 0.9601
#
# Epoch 00019: val_accuracy did not improve from 0.96550
# Epoch 20/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.2126 - accuracy: 0.9296 - val_loss: 0.0858 - val_accuracy: 0.9748
#
# Epoch 00020: val_accuracy improved from 0.96550 to 0.97481, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 21/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1841 - accuracy: 0.9381 - val_loss: 0.1026 - val_accuracy: 0.9643
#
# Epoch 00021: val_accuracy did not improve from 0.97481
# Epoch 22/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1739 - accuracy: 0.9413 - val_loss: 0.1717 - val_accuracy: 0.9403
#
# Epoch 00022: val_accuracy did not improve from 0.97481
# Epoch 23/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1661 - accuracy: 0.9472 - val_loss: 0.0736 - val_accuracy: 0.9756
#
# Epoch 00023: val_accuracy improved from 0.97481 to 0.97558, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 24/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1478 - accuracy: 0.9488 - val_loss: 0.1212 - val_accuracy: 0.9566
#
# Epoch 00024: val_accuracy did not improve from 0.97558
# Epoch 25/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1467 - accuracy: 0.9508 - val_loss: 0.0772 - val_accuracy: 0.9740
#
# Epoch 00025: val_accuracy did not improve from 0.97558
# Epoch 26/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1199 - accuracy: 0.9622 - val_loss: 0.0810 - val_accuracy: 0.9733
#
# Epoch 00026: val_accuracy did not improve from 0.97558
# Epoch 27/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.1033 - accuracy: 0.9652 - val_loss: 0.1233 - val_accuracy: 0.9609
#
# Epoch 00027: val_accuracy did not improve from 0.97558
# Epoch 28/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.1066 - accuracy: 0.9632 - val_loss: 0.1152 - val_accuracy: 0.9539
#
# Epoch 00028: val_accuracy did not improve from 0.97558
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 29/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0896 - accuracy: 0.9679 - val_loss: 0.0329 - val_accuracy: 0.9891
#
# Epoch 00029: val_accuracy improved from 0.97558 to 0.98915, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 30/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0754 - accuracy: 0.9773 - val_loss: 0.0272 - val_accuracy: 0.9895
#
# Epoch 00030: val_accuracy improved from 0.98915 to 0.98953, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 31/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0779 - accuracy: 0.9756 - val_loss: 0.0388 - val_accuracy: 0.9872
#
# Epoch 00031: val_accuracy did not improve from 0.98953
# Epoch 32/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0796 - accuracy: 0.9730 - val_loss: 0.0654 - val_accuracy: 0.9787
#
# Epoch 00032: val_accuracy did not improve from 0.98953
# Epoch 33/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0779 - accuracy: 0.9733 - val_loss: 0.0334 - val_accuracy: 0.9880
#
# Epoch 00033: val_accuracy did not improve from 0.98953
# Epoch 34/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0662 - accuracy: 0.9796 - val_loss: 0.0476 - val_accuracy: 0.9814
#
# Epoch 00034: val_accuracy did not improve from 0.98953
# Epoch 35/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0683 - accuracy: 0.9782 - val_loss: 0.0487 - val_accuracy: 0.9845
#
# Epoch 00035: val_accuracy did not improve from 0.98953
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 36/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0608 - accuracy: 0.9807 - val_loss: 0.0321 - val_accuracy: 0.9899
#
# Epoch 00036: val_accuracy improved from 0.98953 to 0.98992, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 37/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0603 - accuracy: 0.9804 - val_loss: 0.0412 - val_accuracy: 0.9872
#
# Epoch 00037: val_accuracy did not improve from 0.98992
# Epoch 38/100
# 160/160 [==============================] - 3s 18ms/step - loss: 0.0515 - accuracy: 0.9834 - val_loss: 0.0261 - val_accuracy: 0.9895
#
# Epoch 00038: val_accuracy did not improve from 0.98992
# Epoch 39/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0492 - accuracy: 0.9827 - val_loss: 0.0317 - val_accuracy: 0.9880
#
# Epoch 00039: val_accuracy did not improve from 0.98992
# Epoch 40/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0545 - accuracy: 0.9828 - val_loss: 0.0297 - val_accuracy: 0.9884
#
# Epoch 00040: val_accuracy did not improve from 0.98992
# Epoch 41/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0482 - accuracy: 0.9839 - val_loss: 0.0303 - val_accuracy: 0.9876
#
# Epoch 00041: val_accuracy did not improve from 0.98992
# Epoch 42/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0596 - accuracy: 0.9806 - val_loss: 0.0585 - val_accuracy: 0.9826
#
# Epoch 00042: val_accuracy did not improve from 0.98992
# Epoch 43/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0435 - accuracy: 0.9836 - val_loss: 0.0254 - val_accuracy: 0.9903
#
# Epoch 00043: val_accuracy improved from 0.98992 to 0.99031, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 44/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0442 - accuracy: 0.9855 - val_loss: 0.0337 - val_accuracy: 0.9860
#
# Epoch 00044: val_accuracy did not improve from 0.99031
# Epoch 45/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0496 - accuracy: 0.9835 - val_loss: 0.0324 - val_accuracy: 0.9884
#
# Epoch 00045: val_accuracy did not improve from 0.99031
# Epoch 46/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0428 - accuracy: 0.9845 - val_loss: 0.0493 - val_accuracy: 0.9829
#
# Epoch 00046: val_accuracy did not improve from 0.99031
# Epoch 47/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0442 - accuracy: 0.9832 - val_loss: 0.0468 - val_accuracy: 0.9857
#
# Epoch 00047: val_accuracy did not improve from 0.99031
# Epoch 48/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0483 - accuracy: 0.9847 - val_loss: 0.0352 - val_accuracy: 0.9872
#
# Epoch 00048: val_accuracy did not improve from 0.99031
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 49/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0373 - accuracy: 0.9862 - val_loss: 0.0282 - val_accuracy: 0.9888
#
# Epoch 00049: val_accuracy did not improve from 0.99031
# Epoch 50/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0394 - accuracy: 0.9854 - val_loss: 0.0269 - val_accuracy: 0.9907
#
# Epoch 00050: val_accuracy improved from 0.99031 to 0.99070, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 51/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0420 - accuracy: 0.9861 - val_loss: 0.0320 - val_accuracy: 0.9880
#
# Epoch 00051: val_accuracy did not improve from 0.99070
# Epoch 52/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0358 - accuracy: 0.9902 - val_loss: 0.0267 - val_accuracy: 0.9911
#
# Epoch 00052: val_accuracy improved from 0.99070 to 0.99109, saving model to d:/temp/ensembles/model_V2_08\cp.ckpt
# Epoch 53/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0431 - accuracy: 0.9842 - val_loss: 0.0297 - val_accuracy: 0.9876
#
# Epoch 00053: val_accuracy did not improve from 0.99109
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 54/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0409 - accuracy: 0.9860 - val_loss: 0.0347 - val_accuracy: 0.9884
#
# Epoch 00054: val_accuracy did not improve from 0.99109
# Epoch 55/100
# 160/160 [==============================] - 3s 17ms/step - loss: 0.0405 - accuracy: 0.9862 - val_loss: 0.0294 - val_accuracy: 0.9899
#
# Epoch 00055: val_accuracy did not improve from 0.99109
# Epoch 56/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0429 - accuracy: 0.9865 - val_loss: 0.0296 - val_accuracy: 0.9911
#
# Epoch 00056: val_accuracy did not improve from 0.99109
# Epoch 57/100
# 160/160 [==============================] - 2s 15ms/step - loss: 0.0370 - accuracy: 0.9892 - val_loss: 0.0286 - val_accuracy: 0.9903
#
# Epoch 00057: val_accuracy did not improve from 0.99109
# Epoch 58/100
# 160/160 [==============================] - 3s 16ms/step - loss: 0.0367 - accuracy: 0.9889 - val_loss: 0.0314 - val_accuracy: 0.9899
#
# Epoch 00058: val_accuracy did not improve from 0.99109
#
# Epoch 00058: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 00058: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-704-a37f8184fc36> in <module>
#       1 file_path_prefix = f'd:/temp/ensembles/model_V2'
# ----> 2 models_V2, histories_V2 = train_models(dataV2, valset,file_path_prefix)
#       3
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
load_weights(models_V2, file_path_prefix)

# %%
evaluate_models(models_V2)
# Out:
# 66/66 - 1s - loss: 0.0801 - accuracy: 0.9856
# 66/66 - 1s - loss: 0.0516 - accuracy: 0.9882
# 66/66 - 1s - loss: 0.0583 - accuracy: 0.9863
# 66/66 - 1s - loss: 0.0597 - accuracy: 0.9866
# 66/66 - 1s - loss: 0.0665 - accuracy: 0.9861
# 66/66 - 1s - loss: 0.0896 - accuracy: 0.9820
# 66/66 - 1s - loss: 0.0359 - accuracy: 0.9942
# 66/66 - 1s - loss: 0.0892 - accuracy: 0.9818
# 66/66 - 1s - loss: 0.0688 - accuracy: 0.9854
# average accuracy: 98.625

# %%
labels_V2, logits_V2, preds_V2 = get_labels_logits_and_preds(models_V2)
class_preds_V2 = get_class_preds(preds_V2)
class_logits_V2 = get_class_from_sum_of_logits(logits_V2) 

res = get_stats(labels_V2, class_preds_V2, class_logits_V2)
print(res, res[6]/res[0]*100)
# Out:
# [4170, 4060, 8, 57, 0, 45, 4118, 52] 0.9875299760191847

# %% [markdown]
# # Version III - Massive data augmentation

# %% [markdown]
# ### Data augmentation functions

# %%
import tensorflow_addons as tfa

def process_brightness(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 1.0, 0.1, 3.0),0,1)
    return img, label

def process_saturation(image, label):
    
    img = tf.clip_by_value(tfa.image.random_hsv_in_yiq(image, 0.0, 1.0, 3.0, 1.0, 1.0),0,1)
    return img, label

def process_contrast(image, label):
    
    img = tf.clip_by_value(tf.image.random_contrast(image, lower=0.1, upper=3.0, seed=None), 0, 1)
    return img, label

def process_hue(image, label):
    
    img = tf.image.random_hue(image, max_delta=0.2, seed=None)
    return img, label

def process_rotate(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    return img, label

def process_shear(image, label):
    
    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    sx = tf.random.uniform(shape=(), minval=-0.1, maxval=0.1, dtype=tf.dtypes.float32)
    img = tfa.image.transform(img, [1, sx, -sx*32,   0,1,0,  0,0])
    return img, label

def process_translate(image, label):

    img = tfa.image.rotate(image, tf.random.uniform(shape=(), minval=-0.175, maxval=0.175))
    tx = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)
    ty = tf.random.uniform(shape=(), minval=-3, maxval=3, dtype=tf.dtypes.float32)  
    img = tfa.image.translate(img, [tx,ty])
    return img, label

def process_crop(image, label):
    
    c = tf.random.uniform(shape=(), minval=24, maxval=32, dtype=tf.dtypes.float32)
    img = tf.image.random_crop(image, size=[c,c,3])
    img = tf.image.resize(img ,size= [32,32])
    return img, label

# %%
dataV3 = dataset
# color ops
dataV3 = dataV3.map(process_brightness)
dataV3 = dataV3.concatenate(dataset.map(process_contrast))
dataV3 = dataV3.concatenate(dataset.map(process_hue))
dataV3 = dataV3.concatenate(dataset.map(process_saturation))

#geometry ops
dataV3 = dataV3.concatenate(dataset.map(process_rotate))
dataV3 = dataV3.concatenate(dataset.map(process_shear))
dataV3 = dataV3.concatenate(dataset.map(process_translate))
dataV3 = dataV3.concatenate(dataset.map(process_crop))

dataV3 = dataV3.cache()
dataV3 = dataV3.shuffle(buffer_size = 81600)
dataV3 = dataV3.batch(batch_size = BATCH_SIZE)
dataV3 = dataV3.prefetch(buffer_size = AUTOTUNE)

# %%
file_path_prefix = f'd:/temp/ensembles/model_V3'    
models_V3, histories_V3 = train_models(dataV3, valset,file_path_prefix)
# Out:
# Epoch 1/100
# 1275/1275 [==============================] - 32s 14ms/step - loss: 2.0597 - accuracy: 0.3964 - val_loss: 0.1720 - val_accuracy: 0.9512
#
# Epoch 00001: val_accuracy improved from -inf to 0.95116, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.4632 - accuracy: 0.8553 - val_loss: 0.0989 - val_accuracy: 0.9698
#
# Epoch 00002: val_accuracy improved from 0.95116 to 0.96977, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.2465 - accuracy: 0.9216 - val_loss: 0.0604 - val_accuracy: 0.9810
#
# Epoch 00003: val_accuracy improved from 0.96977 to 0.98101, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.1588 - accuracy: 0.9468 - val_loss: 0.0406 - val_accuracy: 0.9884
#
# Epoch 00004: val_accuracy improved from 0.98101 to 0.98837, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 5/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.1077 - accuracy: 0.9644 - val_loss: 0.0262 - val_accuracy: 0.9915
#
# Epoch 00005: val_accuracy improved from 0.98837 to 0.99147, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 6/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0823 - accuracy: 0.9720 - val_loss: 0.0223 - val_accuracy: 0.9911
#
# Epoch 00006: val_accuracy did not improve from 0.99147
# Epoch 7/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0679 - accuracy: 0.9774 - val_loss: 0.0323 - val_accuracy: 0.9899
#
# Epoch 00007: val_accuracy did not improve from 0.99147
# Epoch 8/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0569 - accuracy: 0.9806 - val_loss: 0.0193 - val_accuracy: 0.9919
#
# Epoch 00008: val_accuracy improved from 0.99147 to 0.99186, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 9/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0512 - accuracy: 0.9832 - val_loss: 0.0430 - val_accuracy: 0.9833
#
# Epoch 00009: val_accuracy did not improve from 0.99186
# Epoch 10/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 0.0220 - val_accuracy: 0.9919
#
# Epoch 00010: val_accuracy did not improve from 0.99186
# Epoch 11/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0389 - accuracy: 0.9864 - val_loss: 0.0108 - val_accuracy: 0.9961
#
# Epoch 00011: val_accuracy improved from 0.99186 to 0.99612, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 12/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0336 - accuracy: 0.9883 - val_loss: 0.0108 - val_accuracy: 0.9946
#
# Epoch 00012: val_accuracy did not improve from 0.99612
# Epoch 13/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0322 - accuracy: 0.9887 - val_loss: 0.0154 - val_accuracy: 0.9930
#
# Epoch 00013: val_accuracy did not improve from 0.99612
# Epoch 14/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0286 - accuracy: 0.9902 - val_loss: 0.0112 - val_accuracy: 0.9965
#
# Epoch 00014: val_accuracy improved from 0.99612 to 0.99651, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 15/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0074 - val_accuracy: 0.9981
#
# Epoch 00015: val_accuracy improved from 0.99651 to 0.99806, saving model to d:/temp/ensembles/model_V3_00\cp.ckpt
# Epoch 16/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0252 - accuracy: 0.9911 - val_loss: 0.0292 - val_accuracy: 0.9895
#
# Epoch 00016: val_accuracy did not improve from 0.99806
# Epoch 17/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0249 - accuracy: 0.9913 - val_loss: 0.0085 - val_accuracy: 0.9965
#
# Epoch 00017: val_accuracy did not improve from 0.99806
# Epoch 18/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.0110 - val_accuracy: 0.9965
#
# Epoch 00018: val_accuracy did not improve from 0.99806
# Epoch 19/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0202 - accuracy: 0.9930 - val_loss: 0.0176 - val_accuracy: 0.9946
#
# Epoch 00019: val_accuracy did not improve from 0.99806
# Epoch 20/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0210 - accuracy: 0.9931 - val_loss: 0.0093 - val_accuracy: 0.9961
#
# Epoch 00020: val_accuracy did not improve from 0.99806
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 21/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0183 - accuracy: 0.9943 - val_loss: 0.0112 - val_accuracy: 0.9953
#
# Epoch 00021: val_accuracy did not improve from 0.99806
# Epoch 22/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0144 - accuracy: 0.9946 - val_loss: 0.0102 - val_accuracy: 0.9969
#
# Epoch 00022: val_accuracy did not improve from 0.99806
# Epoch 23/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0083 - val_accuracy: 0.9961
#
# Epoch 00023: val_accuracy did not improve from 0.99806
# Epoch 24/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0105 - val_accuracy: 0.9957
#
# Epoch 00024: val_accuracy did not improve from 0.99806
# Epoch 25/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0078 - val_accuracy: 0.9969
#
# Epoch 00025: val_accuracy did not improve from 0.99806
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 26/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0082 - val_accuracy: 0.9969
#
# Epoch 00026: val_accuracy did not improve from 0.99806
# Epoch 27/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0105 - val_accuracy: 0.9965
#
# Epoch 00027: val_accuracy did not improve from 0.99806
# Epoch 28/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0095 - val_accuracy: 0.9957
#
# Epoch 00028: val_accuracy did not improve from 0.99806
# Epoch 29/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0074 - accuracy: 0.9972 - val_loss: 0.0101 - val_accuracy: 0.9977
#
# Epoch 00029: val_accuracy did not improve from 0.99806
# Epoch 30/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.0065 - accuracy: 0.9978 - val_loss: 0.0107 - val_accuracy: 0.9969
#
# Epoch 00030: val_accuracy did not improve from 0.99806
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 00030: early stopping
# Epoch 1/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 2.0816 - accuracy: 0.4024 - val_loss: 0.1915 - val_accuracy: 0.9589
#
# Epoch 00001: val_accuracy improved from -inf to 0.95891, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.4645 - accuracy: 0.8545 - val_loss: 0.0920 - val_accuracy: 0.9702
#
# Epoch 00002: val_accuracy improved from 0.95891 to 0.97016, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.2373 - accuracy: 0.9236 - val_loss: 0.0677 - val_accuracy: 0.9756
#
# Epoch 00003: val_accuracy improved from 0.97016 to 0.97558, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 0.1534 - accuracy: 0.9501 - val_loss: 0.0378 - val_accuracy: 0.9891
#
# Epoch 00004: val_accuracy improved from 0.97558 to 0.98915, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 5/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1091 - accuracy: 0.9636 - val_loss: 0.0376 - val_accuracy: 0.9872
#
# Epoch 00005: val_accuracy did not improve from 0.98915
# Epoch 6/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0862 - accuracy: 0.9709 - val_loss: 0.0239 - val_accuracy: 0.9915
#
# Epoch 00006: val_accuracy improved from 0.98915 to 0.99147, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 7/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0677 - accuracy: 0.9759 - val_loss: 0.0440 - val_accuracy: 0.9880
#
# Epoch 00007: val_accuracy did not improve from 0.99147
# Epoch 8/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0583 - accuracy: 0.9802 - val_loss: 0.0203 - val_accuracy: 0.9942
#
# Epoch 00008: val_accuracy improved from 0.99147 to 0.99419, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 9/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0496 - accuracy: 0.9832 - val_loss: 0.0165 - val_accuracy: 0.9934
#
# Epoch 00009: val_accuracy did not improve from 0.99419
# Epoch 10/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0424 - accuracy: 0.9855 - val_loss: 0.0109 - val_accuracy: 0.9969
#
# Epoch 00010: val_accuracy improved from 0.99419 to 0.99690, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 11/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0387 - accuracy: 0.9875 - val_loss: 0.0339 - val_accuracy: 0.9884
#
# Epoch 00011: val_accuracy did not improve from 0.99690
# Epoch 12/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0352 - accuracy: 0.9878 - val_loss: 0.0180 - val_accuracy: 0.9926
#
# Epoch 00012: val_accuracy did not improve from 0.99690
# Epoch 13/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0322 - accuracy: 0.9892 - val_loss: 0.0050 - val_accuracy: 0.9977
#
# Epoch 00013: val_accuracy improved from 0.99690 to 0.99767, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 14/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0303 - accuracy: 0.9893 - val_loss: 0.0135 - val_accuracy: 0.9950
#
# Epoch 00014: val_accuracy did not improve from 0.99767
# Epoch 15/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0280 - accuracy: 0.9906 - val_loss: 0.0161 - val_accuracy: 0.9942
#
# Epoch 00015: val_accuracy did not improve from 0.99767
# Epoch 16/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0227 - accuracy: 0.9917 - val_loss: 0.0124 - val_accuracy: 0.9969
#
# Epoch 00016: val_accuracy did not improve from 0.99767
# Epoch 17/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0238 - accuracy: 0.9917 - val_loss: 0.0116 - val_accuracy: 0.9957
#
# Epoch 00017: val_accuracy did not improve from 0.99767
# Epoch 18/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0224 - accuracy: 0.9916 - val_loss: 0.0131 - val_accuracy: 0.9953
#
# Epoch 00018: val_accuracy did not improve from 0.99767
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 19/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0171 - accuracy: 0.9941 - val_loss: 0.0059 - val_accuracy: 0.9981
#
# Epoch 00019: val_accuracy improved from 0.99767 to 0.99806, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 20/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 0.0084 - val_accuracy: 0.9961
#
# Epoch 00020: val_accuracy did not improve from 0.99806
# Epoch 21/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00021: val_accuracy did not improve from 0.99806
# Epoch 22/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0128 - accuracy: 0.9953 - val_loss: 0.0072 - val_accuracy: 0.9969
#
# Epoch 00022: val_accuracy did not improve from 0.99806
# Epoch 23/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0095 - val_accuracy: 0.9965
#
# Epoch 00023: val_accuracy did not improve from 0.99806
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 24/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0111 - accuracy: 0.9962 - val_loss: 0.0043 - val_accuracy: 0.9988
#
# Epoch 00024: val_accuracy improved from 0.99806 to 0.99884, saving model to d:/temp/ensembles/model_V3_01\cp.ckpt
# Epoch 25/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0093 - accuracy: 0.9967 - val_loss: 0.0033 - val_accuracy: 0.9984
#
# Epoch 00025: val_accuracy did not improve from 0.99884
# Epoch 26/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0047 - val_accuracy: 0.9977
#
# Epoch 00026: val_accuracy did not improve from 0.99884
# Epoch 27/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0099 - accuracy: 0.9969 - val_loss: 0.0051 - val_accuracy: 0.9973
#
# Epoch 00027: val_accuracy did not improve from 0.99884
# Epoch 28/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0080 - accuracy: 0.9972 - val_loss: 0.0057 - val_accuracy: 0.9969
#
# Epoch 00028: val_accuracy did not improve from 0.99884
# Epoch 29/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0050 - val_accuracy: 0.9981
#
# Epoch 00029: val_accuracy did not improve from 0.99884
# Epoch 30/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0070 - accuracy: 0.9974 - val_loss: 0.0057 - val_accuracy: 0.9977
#
# Epoch 00030: val_accuracy did not improve from 0.99884
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 31/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0045 - val_accuracy: 0.9984
#
# Epoch 00031: val_accuracy did not improve from 0.99884
# Epoch 32/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00032: val_accuracy did not improve from 0.99884
# Epoch 33/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0041 - val_accuracy: 0.9973
#
# Epoch 00033: val_accuracy did not improve from 0.99884
# Epoch 34/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0031 - val_accuracy: 0.9977
#
# Epoch 00034: val_accuracy did not improve from 0.99884
# Epoch 35/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9977 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00035: val_accuracy did not improve from 0.99884
# Epoch 36/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0059 - val_accuracy: 0.9981
#
# Epoch 00036: val_accuracy did not improve from 0.99884
# Epoch 37/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00037: val_accuracy did not improve from 0.99884
# Epoch 38/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 0.0047 - val_accuracy: 0.9981
#
# Epoch 00038: val_accuracy did not improve from 0.99884
# Epoch 39/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0035 - val_accuracy: 0.9988
#
# Epoch 00039: val_accuracy did not improve from 0.99884
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 40/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0039 - val_accuracy: 0.9988
#
# Epoch 00040: val_accuracy did not improve from 0.99884
# Epoch 41/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0038 - val_accuracy: 0.9988
#
# Epoch 00041: val_accuracy did not improve from 0.99884
# Epoch 42/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.0035 - val_accuracy: 0.9981
#
# Epoch 00042: val_accuracy did not improve from 0.99884
# Epoch 43/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0038 - val_accuracy: 0.9981
#
# Epoch 00043: val_accuracy did not improve from 0.99884
# Epoch 44/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00044: val_accuracy did not improve from 0.99884
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 45/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0036 - val_accuracy: 0.9981
#
# Epoch 00045: val_accuracy did not improve from 0.99884
# Epoch 46/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0037 - val_accuracy: 0.9981
#
# Epoch 00046: val_accuracy did not improve from 0.99884
# Epoch 47/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00047: val_accuracy did not improve from 0.99884
# Epoch 48/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0045 - accuracy: 0.9986 - val_loss: 0.0039 - val_accuracy: 0.9984
#
# Epoch 00048: val_accuracy did not improve from 0.99884
# Epoch 49/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0040 - val_accuracy: 0.9977
#
# Epoch 00049: val_accuracy did not improve from 0.99884
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 00049: early stopping
# Epoch 1/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 2.0536 - accuracy: 0.4030 - val_loss: 0.1837 - val_accuracy: 0.9512
#
# Epoch 00001: val_accuracy improved from -inf to 0.95116, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.4565 - accuracy: 0.8541 - val_loss: 0.0910 - val_accuracy: 0.9682
#
# Epoch 00002: val_accuracy improved from 0.95116 to 0.96822, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.2380 - accuracy: 0.9227 - val_loss: 0.0809 - val_accuracy: 0.9771
#
# Epoch 00003: val_accuracy improved from 0.96822 to 0.97713, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1555 - accuracy: 0.9499 - val_loss: 0.0390 - val_accuracy: 0.9884
#
# Epoch 00004: val_accuracy improved from 0.97713 to 0.98837, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 5/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1086 - accuracy: 0.9635 - val_loss: 0.0360 - val_accuracy: 0.9876
#
# Epoch 00005: val_accuracy did not improve from 0.98837
# Epoch 6/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0838 - accuracy: 0.9713 - val_loss: 0.0269 - val_accuracy: 0.9915
#
# Epoch 00006: val_accuracy improved from 0.98837 to 0.99147, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 7/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0676 - accuracy: 0.9770 - val_loss: 0.0193 - val_accuracy: 0.9922
#
# Epoch 00007: val_accuracy improved from 0.99147 to 0.99225, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 8/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0561 - accuracy: 0.9808 - val_loss: 0.0166 - val_accuracy: 0.9950
#
# Epoch 00008: val_accuracy improved from 0.99225 to 0.99496, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 9/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0493 - accuracy: 0.9833 - val_loss: 0.0304 - val_accuracy: 0.9919
#
# Epoch 00009: val_accuracy did not improve from 0.99496
# Epoch 10/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0428 - accuracy: 0.9843 - val_loss: 0.0167 - val_accuracy: 0.9930
#
# Epoch 00010: val_accuracy did not improve from 0.99496
# Epoch 11/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0381 - accuracy: 0.9862 - val_loss: 0.0197 - val_accuracy: 0.9903
#
# Epoch 00011: val_accuracy did not improve from 0.99496
# Epoch 12/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0355 - accuracy: 0.9878 - val_loss: 0.0415 - val_accuracy: 0.9845
#
# Epoch 00012: val_accuracy did not improve from 0.99496
# Epoch 13/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0321 - accuracy: 0.9888 - val_loss: 0.0219 - val_accuracy: 0.9911
#
# Epoch 00013: val_accuracy did not improve from 0.99496
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 14/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0226 - accuracy: 0.9919 - val_loss: 0.0084 - val_accuracy: 0.9957
#
# Epoch 00014: val_accuracy improved from 0.99496 to 0.99574, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 15/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0209 - accuracy: 0.9932 - val_loss: 0.0043 - val_accuracy: 0.9984
#
# Epoch 00015: val_accuracy improved from 0.99574 to 0.99845, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 16/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.0043 - val_accuracy: 0.9977
#
# Epoch 00016: val_accuracy did not improve from 0.99845
# Epoch 17/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0183 - accuracy: 0.9937 - val_loss: 0.0061 - val_accuracy: 0.9981
#
# Epoch 00017: val_accuracy did not improve from 0.99845
# Epoch 18/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0166 - accuracy: 0.9941 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00018: val_accuracy did not improve from 0.99845
# Epoch 19/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00019: val_accuracy did not improve from 0.99845
# Epoch 20/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0160 - accuracy: 0.9945 - val_loss: 0.0076 - val_accuracy: 0.9965
#
# Epoch 00020: val_accuracy did not improve from 0.99845
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 21/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0135 - accuracy: 0.9954 - val_loss: 0.0044 - val_accuracy: 0.9977
#
# Epoch 00021: val_accuracy did not improve from 0.99845
# Epoch 22/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.0039 - val_accuracy: 0.9981
#
# Epoch 00022: val_accuracy did not improve from 0.99845
# Epoch 23/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0120 - accuracy: 0.9961 - val_loss: 0.0034 - val_accuracy: 0.9988
#
# Epoch 00023: val_accuracy improved from 0.99845 to 0.99884, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 24/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0104 - accuracy: 0.9963 - val_loss: 0.0027 - val_accuracy: 0.9996
#
# Epoch 00024: val_accuracy improved from 0.99884 to 0.99961, saving model to d:/temp/ensembles/model_V3_02\cp.ckpt
# Epoch 25/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0113 - accuracy: 0.9965 - val_loss: 0.0059 - val_accuracy: 0.9965
#
# Epoch 00025: val_accuracy did not improve from 0.99961
# Epoch 26/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0106 - accuracy: 0.9961 - val_loss: 0.0041 - val_accuracy: 0.9984
#
# Epoch 00026: val_accuracy did not improve from 0.99961
# Epoch 27/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0033 - val_accuracy: 0.9988
#
# Epoch 00027: val_accuracy did not improve from 0.99961
# Epoch 28/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0091 - accuracy: 0.9971 - val_loss: 0.0036 - val_accuracy: 0.9992
#
# Epoch 00028: val_accuracy did not improve from 0.99961
# Epoch 29/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0086 - accuracy: 0.9973 - val_loss: 0.0028 - val_accuracy: 0.9984
#
# Epoch 00029: val_accuracy did not improve from 0.99961
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 30/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0084 - accuracy: 0.9970 - val_loss: 0.0030 - val_accuracy: 0.9992
#
# Epoch 00030: val_accuracy did not improve from 0.99961
# Epoch 31/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0066 - accuracy: 0.9978 - val_loss: 0.0038 - val_accuracy: 0.9981
#
# Epoch 00031: val_accuracy did not improve from 0.99961
# Epoch 32/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0049 - val_accuracy: 0.9977
#
# Epoch 00032: val_accuracy did not improve from 0.99961
# Epoch 33/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0030 - val_accuracy: 0.9988
#
# Epoch 00033: val_accuracy did not improve from 0.99961
# Epoch 34/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0073 - accuracy: 0.9974 - val_loss: 0.0041 - val_accuracy: 0.9981
#
# Epoch 00034: val_accuracy did not improve from 0.99961
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 35/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0065 - accuracy: 0.9975 - val_loss: 0.0033 - val_accuracy: 0.9981
#
# Epoch 00035: val_accuracy did not improve from 0.99961
# Epoch 36/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0046 - val_accuracy: 0.9977
#
# Epoch 00036: val_accuracy did not improve from 0.99961
# Epoch 37/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0061 - accuracy: 0.9978 - val_loss: 0.0039 - val_accuracy: 0.9973
#
# Epoch 00037: val_accuracy did not improve from 0.99961
# Epoch 38/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0054 - val_accuracy: 0.9973
#
# Epoch 00038: val_accuracy did not improve from 0.99961
# Epoch 39/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0034 - val_accuracy: 0.9981
#
# Epoch 00039: val_accuracy did not improve from 0.99961
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 00039: early stopping
# Epoch 1/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 2.1110 - accuracy: 0.3860 - val_loss: 0.2049 - val_accuracy: 0.9422
#
# Epoch 00001: val_accuracy improved from -inf to 0.94225, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.4792 - accuracy: 0.8487 - val_loss: 0.1044 - val_accuracy: 0.9659
#
# Epoch 00002: val_accuracy improved from 0.94225 to 0.96589, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.2446 - accuracy: 0.9200 - val_loss: 0.0550 - val_accuracy: 0.9837
#
# Epoch 00003: val_accuracy improved from 0.96589 to 0.98372, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1609 - accuracy: 0.9470 - val_loss: 0.0327 - val_accuracy: 0.9915
#
# Epoch 00004: val_accuracy improved from 0.98372 to 0.99147, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 5/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1072 - accuracy: 0.9641 - val_loss: 0.0353 - val_accuracy: 0.9868
#
# Epoch 00005: val_accuracy did not improve from 0.99147
# Epoch 6/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0815 - accuracy: 0.9736 - val_loss: 0.0257 - val_accuracy: 0.9915
#
# Epoch 00006: val_accuracy did not improve from 0.99147
# Epoch 7/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0672 - accuracy: 0.9775 - val_loss: 0.0267 - val_accuracy: 0.9919
#
# Epoch 00007: val_accuracy improved from 0.99147 to 0.99186, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 8/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0560 - accuracy: 0.9807 - val_loss: 0.0139 - val_accuracy: 0.9938
#
# Epoch 00008: val_accuracy improved from 0.99186 to 0.99380, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 9/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0490 - accuracy: 0.9831 - val_loss: 0.0177 - val_accuracy: 0.9938
#
# Epoch 00009: val_accuracy did not improve from 0.99380
# Epoch 10/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0421 - accuracy: 0.9858 - val_loss: 0.0253 - val_accuracy: 0.9903
#
# Epoch 00010: val_accuracy did not improve from 0.99380
# Epoch 11/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0380 - accuracy: 0.9870 - val_loss: 0.0327 - val_accuracy: 0.9888
#
# Epoch 00011: val_accuracy did not improve from 0.99380
# Epoch 12/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0336 - accuracy: 0.9881 - val_loss: 0.0159 - val_accuracy: 0.9934
#
# Epoch 00012: val_accuracy did not improve from 0.99380
# Epoch 13/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0319 - accuracy: 0.9886 - val_loss: 0.0121 - val_accuracy: 0.9961
#
# Epoch 00013: val_accuracy improved from 0.99380 to 0.99612, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 14/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0315 - accuracy: 0.9895 - val_loss: 0.0111 - val_accuracy: 0.9946
#
# Epoch 00014: val_accuracy did not improve from 0.99612
# Epoch 15/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0288 - accuracy: 0.9901 - val_loss: 0.0106 - val_accuracy: 0.9953
#
# Epoch 00015: val_accuracy did not improve from 0.99612
# Epoch 16/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0253 - accuracy: 0.9904 - val_loss: 0.0142 - val_accuracy: 0.9934
#
# Epoch 00016: val_accuracy did not improve from 0.99612
# Epoch 17/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0242 - accuracy: 0.9915 - val_loss: 0.0162 - val_accuracy: 0.9926
#
# Epoch 00017: val_accuracy did not improve from 0.99612
# Epoch 18/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.0123 - val_accuracy: 0.9965
#
# Epoch 00018: val_accuracy improved from 0.99612 to 0.99651, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 19/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0200 - accuracy: 0.9926 - val_loss: 0.0126 - val_accuracy: 0.9950
#
# Epoch 00019: val_accuracy did not improve from 0.99651
# Epoch 20/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0194 - accuracy: 0.9930 - val_loss: 0.0186 - val_accuracy: 0.9922
#
# Epoch 00020: val_accuracy did not improve from 0.99651
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 21/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0153 - accuracy: 0.9948 - val_loss: 0.0055 - val_accuracy: 0.9984
#
# Epoch 00021: val_accuracy improved from 0.99651 to 0.99845, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 22/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00022: val_accuracy did not improve from 0.99845
# Epoch 23/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.0065 - val_accuracy: 0.9977
#
# Epoch 00023: val_accuracy did not improve from 0.99845
# Epoch 24/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0106 - accuracy: 0.9962 - val_loss: 0.0059 - val_accuracy: 0.9969
#
# Epoch 00024: val_accuracy did not improve from 0.99845
# Epoch 25/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0107 - accuracy: 0.9963 - val_loss: 0.0075 - val_accuracy: 0.9977
#
# Epoch 00025: val_accuracy did not improve from 0.99845
# Epoch 26/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 0.0037 - val_accuracy: 0.9988
#
# Epoch 00026: val_accuracy improved from 0.99845 to 0.99884, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 27/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.0044 - val_accuracy: 0.9984
#
# Epoch 00027: val_accuracy did not improve from 0.99884
# Epoch 28/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0107 - accuracy: 0.9959 - val_loss: 0.0055 - val_accuracy: 0.9984
#
# Epoch 00028: val_accuracy did not improve from 0.99884
# Epoch 29/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0096 - accuracy: 0.9966 - val_loss: 0.0042 - val_accuracy: 0.9988
#
# Epoch 00029: val_accuracy did not improve from 0.99884
# Epoch 30/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0092 - accuracy: 0.9967 - val_loss: 0.0089 - val_accuracy: 0.9953
#
# Epoch 00030: val_accuracy did not improve from 0.99884
# Epoch 31/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 0.0041 - val_accuracy: 0.9988
#
# Epoch 00031: val_accuracy did not improve from 0.99884
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 32/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0072 - accuracy: 0.9976 - val_loss: 0.0029 - val_accuracy: 0.9984
#
# Epoch 00032: val_accuracy did not improve from 0.99884
# Epoch 33/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0051 - val_accuracy: 0.9981
#
# Epoch 00033: val_accuracy did not improve from 0.99884
# Epoch 34/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0018 - val_accuracy: 0.9996
#
# Epoch 00034: val_accuracy improved from 0.99884 to 0.99961, saving model to d:/temp/ensembles/model_V3_03\cp.ckpt
# Epoch 35/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0034 - val_accuracy: 0.9992
#
# Epoch 00035: val_accuracy did not improve from 0.99961
# Epoch 36/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9978 - val_loss: 0.0024 - val_accuracy: 0.9992
#
# Epoch 00036: val_accuracy did not improve from 0.99961
# Epoch 37/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0063 - val_accuracy: 0.9977
#
# Epoch 00037: val_accuracy did not improve from 0.99961
# Epoch 38/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0037 - val_accuracy: 0.9988
#
# Epoch 00038: val_accuracy did not improve from 0.99961
# Epoch 39/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0033 - val_accuracy: 0.9992
#
# Epoch 00039: val_accuracy did not improve from 0.99961
#
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 40/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0030 - val_accuracy: 0.9992
#
# Epoch 00040: val_accuracy did not improve from 0.99961
# Epoch 41/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0039 - accuracy: 0.9986 - val_loss: 0.0022 - val_accuracy: 0.9996
#
# Epoch 00041: val_accuracy did not improve from 0.99961
# Epoch 42/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0037 - val_accuracy: 0.9992
#
# Epoch 00042: val_accuracy did not improve from 0.99961
# Epoch 43/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0045 - accuracy: 0.9983 - val_loss: 0.0022 - val_accuracy: 0.9996
#
# Epoch 00043: val_accuracy did not improve from 0.99961
# Epoch 44/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0048 - accuracy: 0.9983 - val_loss: 0.0024 - val_accuracy: 0.9996
#
# Epoch 00044: val_accuracy did not improve from 0.99961
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 45/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 0.0026 - val_accuracy: 0.9996
#
# Epoch 00045: val_accuracy did not improve from 0.99961
# Epoch 46/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0029 - val_accuracy: 0.9988
#
# Epoch 00046: val_accuracy did not improve from 0.99961
# Epoch 47/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0026 - val_accuracy: 0.9996
#
# Epoch 00047: val_accuracy did not improve from 0.99961
# Epoch 48/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0032 - val_accuracy: 0.9988
#
# Epoch 00048: val_accuracy did not improve from 0.99961
# Epoch 49/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0028 - val_accuracy: 0.9992
#
# Epoch 00049: val_accuracy did not improve from 0.99961
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 00049: early stopping
# Epoch 1/100
# 1275/1275 [==============================] - 18s 13ms/step - loss: 2.0901 - accuracy: 0.3881 - val_loss: 0.1782 - val_accuracy: 0.9500
#
# Epoch 00001: val_accuracy improved from -inf to 0.95000, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.4697 - accuracy: 0.8524 - val_loss: 0.1107 - val_accuracy: 0.9671
#
# Epoch 00002: val_accuracy improved from 0.95000 to 0.96705, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.2390 - accuracy: 0.9237 - val_loss: 0.0393 - val_accuracy: 0.9891
#
# Epoch 00003: val_accuracy improved from 0.96705 to 0.98915, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1524 - accuracy: 0.9501 - val_loss: 0.0515 - val_accuracy: 0.9872
#
# Epoch 00004: val_accuracy did not improve from 0.98915
# Epoch 5/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1060 - accuracy: 0.9646 - val_loss: 0.0322 - val_accuracy: 0.9872
#
# Epoch 00005: val_accuracy did not improve from 0.98915
# Epoch 6/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0827 - accuracy: 0.9725 - val_loss: 0.0152 - val_accuracy: 0.9953
#
# Epoch 00006: val_accuracy improved from 0.98915 to 0.99535, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 7/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0673 - accuracy: 0.9774 - val_loss: 0.0177 - val_accuracy: 0.9950
#
# Epoch 00007: val_accuracy did not improve from 0.99535
# Epoch 8/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0579 - accuracy: 0.9804 - val_loss: 0.0168 - val_accuracy: 0.9946
#
# Epoch 00008: val_accuracy did not improve from 0.99535
# Epoch 9/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0479 - accuracy: 0.9839 - val_loss: 0.0151 - val_accuracy: 0.9946
#
# Epoch 00009: val_accuracy did not improve from 0.99535
# Epoch 10/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0444 - accuracy: 0.9849 - val_loss: 0.0213 - val_accuracy: 0.9903
#
# Epoch 00010: val_accuracy did not improve from 0.99535
# Epoch 11/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0385 - accuracy: 0.9868 - val_loss: 0.0153 - val_accuracy: 0.9950
#
# Epoch 00011: val_accuracy did not improve from 0.99535
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 12/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0287 - accuracy: 0.9902 - val_loss: 0.0126 - val_accuracy: 0.9950
#
# Epoch 00012: val_accuracy did not improve from 0.99535
# Epoch 13/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0227 - accuracy: 0.9921 - val_loss: 0.0061 - val_accuracy: 0.9981
#
# Epoch 00013: val_accuracy improved from 0.99535 to 0.99806, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 14/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0225 - accuracy: 0.9925 - val_loss: 0.0078 - val_accuracy: 0.9965
#
# Epoch 00014: val_accuracy did not improve from 0.99806
# Epoch 15/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0196 - accuracy: 0.9933 - val_loss: 0.0073 - val_accuracy: 0.9969
#
# Epoch 00015: val_accuracy did not improve from 0.99806
# Epoch 16/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0189 - accuracy: 0.9936 - val_loss: 0.0080 - val_accuracy: 0.9965
#
# Epoch 00016: val_accuracy did not improve from 0.99806
# Epoch 17/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.0082 - val_accuracy: 0.9965
#
# Epoch 00017: val_accuracy did not improve from 0.99806
# Epoch 18/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0089 - val_accuracy: 0.9965
#
# Epoch 00018: val_accuracy did not improve from 0.99806
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 19/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.0040 - val_accuracy: 0.9988
#
# Epoch 00019: val_accuracy improved from 0.99806 to 0.99884, saving model to d:/temp/ensembles/model_V3_04\cp.ckpt
# Epoch 20/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00020: val_accuracy did not improve from 0.99884
# Epoch 21/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 0.0054 - val_accuracy: 0.9984
#
# Epoch 00021: val_accuracy did not improve from 0.99884
# Epoch 22/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00022: val_accuracy did not improve from 0.99884
# Epoch 23/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.0060 - val_accuracy: 0.9977
#
# Epoch 00023: val_accuracy did not improve from 0.99884
# Epoch 24/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00024: val_accuracy did not improve from 0.99884
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 25/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00025: val_accuracy did not improve from 0.99884
# Epoch 26/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0090 - accuracy: 0.9967 - val_loss: 0.0056 - val_accuracy: 0.9981
#
# Epoch 00026: val_accuracy did not improve from 0.99884
# Epoch 27/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0095 - accuracy: 0.9969 - val_loss: 0.0054 - val_accuracy: 0.9981
#
# Epoch 00027: val_accuracy did not improve from 0.99884
# Epoch 28/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0080 - accuracy: 0.9971 - val_loss: 0.0043 - val_accuracy: 0.9981
#
# Epoch 00028: val_accuracy did not improve from 0.99884
# Epoch 29/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0042 - val_accuracy: 0.9984
#
# Epoch 00029: val_accuracy did not improve from 0.99884
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 30/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0088 - accuracy: 0.9970 - val_loss: 0.0029 - val_accuracy: 0.9988
#
# Epoch 00030: val_accuracy did not improve from 0.99884
# Epoch 31/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0076 - accuracy: 0.9974 - val_loss: 0.0036 - val_accuracy: 0.9984
#
# Epoch 00031: val_accuracy did not improve from 0.99884
# Epoch 32/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0072 - accuracy: 0.9973 - val_loss: 0.0051 - val_accuracy: 0.9981
#
# Epoch 00032: val_accuracy did not improve from 0.99884
# Epoch 33/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0040 - val_accuracy: 0.9981
#
# Epoch 00033: val_accuracy did not improve from 0.99884
# Epoch 34/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00034: val_accuracy did not improve from 0.99884
# Epoch 35/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0037 - val_accuracy: 0.9981
#
# Epoch 00035: val_accuracy did not improve from 0.99884
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 36/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00036: val_accuracy did not improve from 0.99884
# Epoch 37/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0068 - accuracy: 0.9974 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00037: val_accuracy did not improve from 0.99884
# Epoch 38/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00038: val_accuracy did not improve from 0.99884
# Epoch 39/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0053 - val_accuracy: 0.9981
#
# Epoch 00039: val_accuracy did not improve from 0.99884
# Epoch 40/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0047 - val_accuracy: 0.9981
#
# Epoch 00040: val_accuracy did not improve from 0.99884
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 41/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00041: val_accuracy did not improve from 0.99884
# Epoch 42/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 0.0043 - val_accuracy: 0.9981
#
# Epoch 00042: val_accuracy did not improve from 0.99884
# Epoch 43/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0042 - val_accuracy: 0.9981
#
# Epoch 00043: val_accuracy did not improve from 0.99884
# Epoch 44/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00044: val_accuracy did not improve from 0.99884
# Epoch 45/100
# ...
#
# Epoch 00034: val_accuracy did not improve from 0.99884
# Epoch 35/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0054 - val_accuracy: 0.9988
#
# Epoch 00035: val_accuracy did not improve from 0.99884
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 00035: early stopping
# Epoch 1/100
# 1275/1275 [==============================] - 18s 14ms/step - loss: 2.0602 - accuracy: 0.3953 - val_loss: 0.1847 - val_accuracy: 0.9570
#
# Epoch 00001: val_accuracy improved from -inf to 0.95698, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 2/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.4700 - accuracy: 0.8503 - val_loss: 0.0932 - val_accuracy: 0.9733
#
# Epoch 00002: val_accuracy improved from 0.95698 to 0.97326, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 3/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.2391 - accuracy: 0.9221 - val_loss: 0.0626 - val_accuracy: 0.9775
#
# Epoch 00003: val_accuracy improved from 0.97326 to 0.97752, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 4/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1564 - accuracy: 0.9481 - val_loss: 0.0374 - val_accuracy: 0.9884
#
# Epoch 00004: val_accuracy improved from 0.97752 to 0.98837, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 5/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.1115 - accuracy: 0.9628 - val_loss: 0.0374 - val_accuracy: 0.9864
#
# Epoch 00005: val_accuracy did not improve from 0.98837
# Epoch 6/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0844 - accuracy: 0.9709 - val_loss: 0.0595 - val_accuracy: 0.9779
#
# Epoch 00006: val_accuracy did not improve from 0.98837
# Epoch 7/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0665 - accuracy: 0.9768 - val_loss: 0.0135 - val_accuracy: 0.9973
#
# Epoch 00007: val_accuracy improved from 0.98837 to 0.99729, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 8/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0584 - accuracy: 0.9803 - val_loss: 0.0251 - val_accuracy: 0.9915
#
# Epoch 00008: val_accuracy did not improve from 0.99729
# Epoch 9/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0481 - accuracy: 0.9832 - val_loss: 0.0494 - val_accuracy: 0.9806
#
# Epoch 00009: val_accuracy did not improve from 0.99729
# Epoch 10/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0435 - accuracy: 0.9853 - val_loss: 0.0103 - val_accuracy: 0.9953
#
# Epoch 00010: val_accuracy did not improve from 0.99729
# Epoch 11/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0371 - accuracy: 0.9874 - val_loss: 0.0096 - val_accuracy: 0.9965
#
# Epoch 00011: val_accuracy did not improve from 0.99729
# Epoch 12/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0364 - accuracy: 0.9879 - val_loss: 0.0144 - val_accuracy: 0.9938
#
# Epoch 00012: val_accuracy did not improve from 0.99729
# Epoch 13/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0333 - accuracy: 0.9882 - val_loss: 0.0090 - val_accuracy: 0.9965
#
# Epoch 00013: val_accuracy did not improve from 0.99729
# Epoch 14/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0333 - accuracy: 0.9890 - val_loss: 0.0075 - val_accuracy: 0.9969
#
# Epoch 00014: val_accuracy did not improve from 0.99729
# Epoch 15/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0257 - accuracy: 0.9913 - val_loss: 0.0127 - val_accuracy: 0.9953
#
# Epoch 00015: val_accuracy did not improve from 0.99729
# Epoch 16/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0264 - accuracy: 0.9910 - val_loss: 0.0187 - val_accuracy: 0.9922
#
# Epoch 00016: val_accuracy did not improve from 0.99729
# Epoch 17/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0243 - accuracy: 0.9913 - val_loss: 0.0113 - val_accuracy: 0.9965
#
# Epoch 00017: val_accuracy did not improve from 0.99729
# Epoch 18/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0230 - accuracy: 0.9917 - val_loss: 0.0127 - val_accuracy: 0.9957
#
# Epoch 00018: val_accuracy did not improve from 0.99729
# Epoch 19/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0206 - accuracy: 0.9929 - val_loss: 0.0070 - val_accuracy: 0.9981
#
# Epoch 00019: val_accuracy improved from 0.99729 to 0.99806, saving model to d:/temp/ensembles/model_V3_08\cp.ckpt
# Epoch 20/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0210 - accuracy: 0.9928 - val_loss: 0.0136 - val_accuracy: 0.9950
#
# Epoch 00020: val_accuracy did not improve from 0.99806
# Epoch 21/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0203 - accuracy: 0.9928 - val_loss: 0.0083 - val_accuracy: 0.9973
#
# Epoch 00021: val_accuracy did not improve from 0.99806
# Epoch 22/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0194 - accuracy: 0.9932 - val_loss: 0.0101 - val_accuracy: 0.9961
#
# Epoch 00022: val_accuracy did not improve from 0.99806
# Epoch 23/100
# 1275/1275 [==============================] - 17s 14ms/step - loss: 0.0171 - accuracy: 0.9940 - val_loss: 0.0125 - val_accuracy: 0.9953
#
# Epoch 00023: val_accuracy did not improve from 0.99806
# Epoch 24/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0184 - accuracy: 0.9938 - val_loss: 0.0111 - val_accuracy: 0.9965
#
# Epoch 00024: val_accuracy did not improve from 0.99806
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 25/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0081 - val_accuracy: 0.9953
#
# Epoch 00025: val_accuracy did not improve from 0.99806
# Epoch 26/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0105 - accuracy: 0.9961 - val_loss: 0.0097 - val_accuracy: 0.9965
#
# Epoch 00026: val_accuracy did not improve from 0.99806
# Epoch 27/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 0.0102 - val_accuracy: 0.9965
#
# Epoch 00027: val_accuracy did not improve from 0.99806
# Epoch 28/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0086 - val_accuracy: 0.9965
#
# Epoch 00028: val_accuracy did not improve from 0.99806
# Epoch 29/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0096 - accuracy: 0.9965 - val_loss: 0.0077 - val_accuracy: 0.9973
#
# Epoch 00029: val_accuracy did not improve from 0.99806
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 30/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0043 - val_accuracy: 0.9969
#
# Epoch 00030: val_accuracy did not improve from 0.99806
# Epoch 31/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0059 - val_accuracy: 0.9973
#
# Epoch 00031: val_accuracy did not improve from 0.99806
# Epoch 32/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0064 - accuracy: 0.9977 - val_loss: 0.0072 - val_accuracy: 0.9973
#
# Epoch 00032: val_accuracy did not improve from 0.99806
# Epoch 33/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0061 - val_accuracy: 0.9981
#
# Epoch 00033: val_accuracy did not improve from 0.99806
# Epoch 34/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0052 - val_accuracy: 0.9981
#
# Epoch 00034: val_accuracy did not improve from 0.99806
# Epoch 35/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.0058 - val_accuracy: 0.9973
#
# Epoch 00035: val_accuracy did not improve from 0.99806
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 36/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00036: val_accuracy did not improve from 0.99806
# Epoch 37/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0051 - accuracy: 0.9981 - val_loss: 0.0061 - val_accuracy: 0.9973
#
# Epoch 00037: val_accuracy did not improve from 0.99806
# Epoch 38/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0054 - val_accuracy: 0.9977
#
# Epoch 00038: val_accuracy did not improve from 0.99806
# Epoch 39/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00039: val_accuracy did not improve from 0.99806
# Epoch 40/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0064 - val_accuracy: 0.9977
#
# Epoch 00040: val_accuracy did not improve from 0.99806
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 41/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0052 - val_accuracy: 0.9973
#
# Epoch 00041: val_accuracy did not improve from 0.99806
# Epoch 42/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00042: val_accuracy did not improve from 0.99806
# Epoch 43/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0041 - val_accuracy: 0.9981
#
# Epoch 00043: val_accuracy did not improve from 0.99806
# Epoch 44/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00044: val_accuracy did not improve from 0.99806
# Epoch 45/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0047 - accuracy: 0.9983 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00045: val_accuracy did not improve from 0.99806
# Epoch 46/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.0043 - val_accuracy: 0.9981
#
# Epoch 00046: val_accuracy did not improve from 0.99806
# Epoch 47/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00047: val_accuracy did not improve from 0.99806
# Epoch 48/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0041 - accuracy: 0.9985 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00048: val_accuracy did not improve from 0.99806
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 49/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0055 - val_accuracy: 0.9981
#
# Epoch 00049: val_accuracy did not improve from 0.99806
# Epoch 50/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9981
#
# Epoch 00050: val_accuracy did not improve from 0.99806
# Epoch 51/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0032 - accuracy: 0.9989 - val_loss: 0.0047 - val_accuracy: 0.9981
#
# Epoch 00051: val_accuracy did not improve from 0.99806
# Epoch 52/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0028 - accuracy: 0.9990 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00052: val_accuracy did not improve from 0.99806
# Epoch 53/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00053: val_accuracy did not improve from 0.99806
#
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 54/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0038 - accuracy: 0.9984 - val_loss: 0.0038 - val_accuracy: 0.9981
#
# Epoch 00054: val_accuracy did not improve from 0.99806
# Epoch 55/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00055: val_accuracy did not improve from 0.99806
# Epoch 56/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0042 - accuracy: 0.9985 - val_loss: 0.0041 - val_accuracy: 0.9981
#
# Epoch 00056: val_accuracy did not improve from 0.99806
# Epoch 57/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00057: val_accuracy did not improve from 0.99806
# Epoch 58/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00058: val_accuracy did not improve from 0.99806
# Epoch 59/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0049 - val_accuracy: 0.9981
#
# Epoch 00059: val_accuracy did not improve from 0.99806
#
# Epoch 00059: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 60/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0047 - val_accuracy: 0.9981
#
# Epoch 00060: val_accuracy did not improve from 0.99806
# Epoch 61/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00061: val_accuracy did not improve from 0.99806
# Epoch 62/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0027 - accuracy: 0.9993 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00062: val_accuracy did not improve from 0.99806
# Epoch 63/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.0043 - val_accuracy: 0.9981
#
# Epoch 00063: val_accuracy did not improve from 0.99806
# Epoch 64/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00064: val_accuracy did not improve from 0.99806
#
# Epoch 00064: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 65/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.0046 - val_accuracy: 0.9981
#
# Epoch 00065: val_accuracy did not improve from 0.99806
# Epoch 66/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00066: val_accuracy did not improve from 0.99806
# Epoch 67/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00067: val_accuracy did not improve from 0.99806
# Epoch 68/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0044 - val_accuracy: 0.9981
#
# Epoch 00068: val_accuracy did not improve from 0.99806
# Epoch 69/100
# 1275/1275 [==============================] - 17s 13ms/step - loss: 0.0037 - accuracy: 0.9988 - val_loss: 0.0045 - val_accuracy: 0.9981
#
# Epoch 00069: val_accuracy did not improve from 0.99806
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 00069: early stopping
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-710-f166bf70acac> in <module>
#       1 file_path_prefix = f'd:/temp/ensembles/model_V3'
# ----> 2 models_V3, histories_V3 = train_models(dataV3, valset,file_path_prefix)
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
load_weights(models_V3, file_path_prefix)
evaluate_models(models_V3)
# Out:
# 66/66 - 1s - loss: 0.0326 - accuracy: 0.9947
# 66/66 - 1s - loss: 0.0374 - accuracy: 0.9914
# 66/66 - 1s - loss: 0.0362 - accuracy: 0.9945
# 66/66 - 1s - loss: 0.0340 - accuracy: 0.9947
# 66/66 - 1s - loss: 0.0361 - accuracy: 0.9928
# 66/66 - 1s - loss: 0.0368 - accuracy: 0.9962
# 66/66 - 1s - loss: 0.0351 - accuracy: 0.9926
# 66/66 - 1s - loss: 0.0307 - accuracy: 0.9918
# 66/66 - 1s - loss: 0.0489 - accuracy: 0.9911
# average accuracy: 99.331

# %%
labels_V3, logits_V3, preds_V3 = get_labels_logits_and_preds(models_V3)
class_preds_V3 = get_class_preds(preds_V3)
class_logits_V3 = get_class_from_sum_of_logits(logits_V3) 

res = get_stats(labels_V3, class_preds_V3, class_logits_V3)
print(res, res[6]/res[0])
# Out:
# [4170, 4115, 10, 30, 0, 15, 4147, 23] 0.994484412470024

# %% [markdown]
# # Stacked Ensemble

# %%
## Build list of inputs and labels for test class

test_logits_preds = []

for i in range(test_dataset_length):
    
    aux = []   
    for m in range(NUM_MODELS):        
        aux.extend(logits[m][i])
        
    test_logits_preds.append(aux)
    
    
## Compute logit predictions and training labels
    
logits_train = [[] for _ in range(NUM_MODELS)]
labels_aux = []
for images, labs in dataSolo.take(-1):
    
    labels_aux.extend(labs.numpy())
    for i in range(NUM_MODELS):
        
        logits_train[i].extend(models_V3[i][1].predict(images))
        
labels_train = [np.argmax(i) for i in labels_aux]  

## Build list of train inputs

train_logits_preds = []

for i in range(dataset_length):
    
    aux = []
    
    for m in range(NUM_MODELS):
        
        aux.extend(logits_train[m][i])
        
    train_logits_preds.append(aux)

# %%
print(len(labels))

# %%
stack_model  = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(len(train_logits_preds[0]),)),

  tf.keras.layers.Dense(32),    
  LeakyReLU(alpha=0.0),BatchNormalization(),
  tf.keras.layers.Dropout(0.5),
  tf.keras.layers.Dense(32),    
  LeakyReLU(alpha=0.0),BatchNormalization(),
  tf.keras.layers.Dropout(0.5),

  tf.keras.layers.Dense(8, activation='softmax')
])

stack_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
stack_model.fit(np.asarray(train_logits_preds),np.asarray(labels_train),epochs=10, batch_size=32,
                        validation_data = (np.asarray(test_logits_preds), np.asarray(labels)))
# Out:
# Epoch 1/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0309 - accuracy: 0.9923 - val_loss: 0.0409 - val_accuracy: 0.9885
# Epoch 2/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0289 - accuracy: 0.9911 - val_loss: 0.0418 - val_accuracy: 0.9882
# Epoch 3/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0247 - accuracy: 0.9937 - val_loss: 0.0485 - val_accuracy: 0.9880
# Epoch 4/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0294 - accuracy: 0.9919 - val_loss: 0.0441 - val_accuracy: 0.9880
# Epoch 5/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0221 - accuracy: 0.9938 - val_loss: 0.0523 - val_accuracy: 0.9871
# Epoch 6/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0222 - accuracy: 0.9944 - val_loss: 0.0474 - val_accuracy: 0.9878
# Epoch 7/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.0497 - val_accuracy: 0.9880
# Epoch 8/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0185 - accuracy: 0.9951 - val_loss: 0.0405 - val_accuracy: 0.9892
# Epoch 9/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0176 - accuracy: 0.9955 - val_loss: 0.0536 - val_accuracy: 0.9873
# Epoch 10/10
# 319/319 [==============================] - 2s 6ms/step - loss: 0.0157 - accuracy: 0.9959 - val_loss: 0.0544 - val_accuracy: 0.9871

# %%
pred = stack_model.predict(np.asarray(test_logits_preds))

# %%
correct = 0

for i in range(test_dataset_length):
    if np.argmax(pred[i]) == labels[i] :
        correct += 1
        
print(correct)
# Out:
# 4117
